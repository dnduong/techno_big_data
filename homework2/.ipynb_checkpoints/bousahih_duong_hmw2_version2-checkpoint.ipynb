# %% [markdown]
# # Propaganda, start the `spark` session
#
# > For SQL users, Spark SQL provides state-of-the-art SQL performance and maintains compatibility with Shark/Hive. In particular, like Shark, Spark SQL supports all existing Hive data formats, user-defined functions (UDF), and the Hive metastore.
#
# > For Spark users, Spark SQL becomes the narrow-waist for manipulating (semi-) structured data as well as ingesting data from sources that provide schema, such as JSON, Parquet, Hive, or EDWs. It truly unifies SQL and sophisticated analysis, allowing users to mix and match SQL and more imperative programming APIs for advanced analytics.
#
# > For open source hackers, Spark SQL proposes a novel, elegant way of building query planners. It is incredibly easy to add new optimizations under this framework.
#
# > Internally, a structured query is a Catalyst tree of (logical and physical) relational operators and expressions.

# %%
# import the usual suspects
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from pathlib import Path
import sys
import timeit

# %matplotlib inline
import seaborn as sns

sns.set_context("notebook", font_scale=1.2)

# %% [markdown]
# During the session, we will use classes and functions exported by `pyspark`

# %%
# spark
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.sql import Window
from pyspark.sql.functions import col
import pyspark.sql.functions as fn
from pyspark.sql.catalog import Catalog
from pyspark.sql.types import StructType, StructField
from pyspark.sql.types import IntegerType, StringType

# %% [markdown]
# Start the `SparkSession`

# %%
conf = SparkConf().setAppName("Spark SQL Illustrations")
sc = SparkContext(conf=conf)

spark = (SparkSession
    .builder
    .appName("Spark SQL")
    .getOrCreate()
)

# %% [markdown]
# US Baby Names 1880-2017
# =======================
#
#
# Description
# : US baby names provided by the SSA.
#
# This dataset contains all names used
# for at least 5 children of either sex during a year.
#
#
# The file is made of `1924665` lines and  4 columns.
#
# ```
# |-- name: string (nullable = true)
#     |-- n: integer (nullable = true)
#     |-- sex: string (nullable = true)
#     |-- year: integer (nullable = true)
# ```
#
# Each row indicates for a given name, sex, and year the number of babies
# of the given sex who were given that name during the given year. Names
# with less than 5 occurrences during the year were note recorded.
#
# |    name|  n|sex|year|
# |:--------|:---:|:---:|:----:|
# |  Emilia|112|  F|1985|
# |   Kelsi|112|  F|1985|
# |  Margot|112|  F|1985|
# |  Mariam|112|  F|1985|
# |Scarlett|112|  F|1985|
#
# First, we download the data if it's not there yet

# %%
import requests, zipfile, io
from pathlib import Path

path = Path('babynames_short.csv')
if not path.exists():
    url = "https://stephanegaiffas.github.io/big_data_course/data/babynames_short.csv.zip"
    r = requests.get(url)
    z = zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall(path='./')

# %% [markdown]
# Load `babynames` from a `csv` file

# %%
df_sp = spark.read\
             .format('csv')\
             .option("header", "true")\
             .option("mode", "FAILFAST")\
             .option("inferSchema", "true")\
             .option("sep", ",")\
             .load("babynames_short.csv")

df_sp.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- n: integer (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- year: double (nullable = true)

# %% [markdown]
# Ensure that the dataframe has the following schema:
#
#     root
#         |-- name: string (nullable = true)
#         |-- n: integer (nullable = true)
#         |-- sex: string (nullable = true)
#         |-- year: integer (nullable = true)

# %%
df_sp = df_sp.withColumn("year", df_sp.year.cast("int"))
df_sp.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- n: integer (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- year: integer (nullable = true)

# %%
df_sp.explain()
# Out:
# == Physical Plan ==
# *(1) Project [name#10, n#11, sex#12, cast(year#13 as int) AS year#18]
# +- *(1) FileScan csv [name#10,n#11,sex#12,year#13] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/opt/polynote/notebooks/homework/techno_big_data/homework2/babynames_short..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<name:string,n:int,sex:string,year:double>

# %% [markdown]
# SQL versus spark-Dataframe API
# =================================
#
# >  Dataset API vs SQL
#
# > Spark SQL supports two "modes" to write structured queries: Dataset API and SQL. SQL Mode is used to express structured queries using SQL statements using SparkSession.sql operator, expr standard function and spark-sql command-line tool.
#
# > Some structured queries can be expressed much easier using Dataset API, but there are some that are only possible in SQL. In other words, you may find mixing Dataset API and SQL modes challenging yet rewarding.
#
# > What is important, and one of the reasons why Spark SQL has been so successful, is that there is no performance difference between the modes. Whatever mode you use to write your structured queries, they all end up as a tree of Catalyst relational data structures. And, yes, you could consider writing structured queries using Catalyst directly, but that could quickly become unwieldy for maintenance (i.e. finding Spark SQL developers who could be comfortable with it as well as being fairly low-level and therefore possibly too dependent on a specific Spark SQL version).
#
# Warmup:  compute the 10 most popular names given to babies in year 2000.
# ======================================================================
#
# ## Using `spark.sql()`
#
# In order to use mode `sql`, create a temporary view from the `DataFrame`.
#
# 1. What are temporary views made of?
# 1. Are there other kind of views in spark's world?

# %% [markdown]
# Affichage des vues temporaires - metabase.

# %%
Catalog(spark).listTables()
# Out:
# []

# %% [markdown]
# - What are tempory views made of ?
#
# Answer : (à faire)

# %% [markdown]
# - Are there other kind of views in spark's world ?
#
# Answer : (à faire)

# %%
# TODO: 
df_sp.createOrReplaceTempView("babynames")
Catalog(spark).listTables()
# Out:
# [Table(name='babynames', database=None, description=None, tableType='TEMPORARY', isTemporary=True)]

# %% [markdown]
# ## A query is a plain SQL query embodied in a string.

# %%
query = """
SELECT name,sex,n,year
FROM babynames
WHERE year == {0}
ORDER BY n DESC
LIMIT 10
"""

# %%
spark.sql(query.format(2000)).show()
# Out:
# +-----------+---+-----+----+
# |       name|sex|    n|year|
# +-----------+---+-----+----+
# |      Jacob|  M|34471|2000|
# |    Michael|  M|32035|2000|
# |    Matthew|  M|28572|2000|
# |     Joshua|  M|27538|2000|
# |      Emily|  F|25953|2000|
# |Christopher|  M|24931|2000|
# |   Nicholas|  M|24652|2000|
# |     Andrew|  M|23639|2000|
# |     Hannah|  F|23080|2000|
# |     Joseph|  M|22825|2000|
# +-----------+---+-----+----+

# %% [markdown]
# > This phrasing is not consistent with the DRY principle. Fix this using formatted strings.
#
# ## Using the dataframe/dataset API
#
# This can also be done using Spark SQL API.
#
# ### Pedestrian approach
#
# 1. First select `10` most popular names for girls in year `2000`, define `spark` dataframe
# `top10_2000_f`.
# 1. Does the definition of `top10_2000_f` involve _transformations_, _actions_ or both?
# 1. What is the type of the result returned by `top10_2000_f.take(2)`? the type of elements of the result?

# %%
# top10_2000_f = TODO:
def create_top10(sex):
    return df_sp.where('sex = '+sex+' AND year = 2000')\
                .orderBy(df_sp.n.desc())\
                .limit(10)

top10_2000_f = create_top10('"F"')
top10_2000_f.show()
# Out:
# +---------+-----+---+----+
# |     name|    n|sex|year|
# +---------+-----+---+----+
# |    Emily|25953|  F|2000|
# |   Hannah|23080|  F|2000|
# |  Madison|19967|  F|2000|
# |   Ashley|17997|  F|2000|
# |    Sarah|17697|  F|2000|
# |   Alexis|17629|  F|2000|
# | Samantha|17266|  F|2000|
# |  Jessica|15709|  F|2000|
# |Elizabeth|15094|  F|2000|
# |   Taylor|15078|  F|2000|
# +---------+-----+---+----+

# %% [markdown]
# - Does the definition of top10_2000_f involve transformations_, _actions or both ?
#
# Answer : (à faire)

# %% [markdown]
# - What is the type of the result returned by top10_2000_f.take(2) ? the type of elements of the result ?
#
# Answer : (à faire)

# %% [markdown]
# 1. Do the same thing for boys.

# %%
# top10_2000_m = TODO:
top10_2000_m = create_top10('"M"')
top10_2000_m.show()
# Out:
# +-----------+-----+---+----+
# |       name|    n|sex|year|
# +-----------+-----+---+----+
# |      Jacob|34471|  M|2000|
# |    Michael|32035|  M|2000|
# |    Matthew|28572|  M|2000|
# |     Joshua|27538|  M|2000|
# |Christopher|24931|  M|2000|
# |   Nicholas|24652|  M|2000|
# |     Andrew|23639|  M|2000|
# |     Joseph|22825|  M|2000|
# |     Daniel|22312|  M|2000|
# |      Tyler|21503|  M|2000|
# +-----------+-----+---+----+

# %% [markdown]
# 1. Compute the _union_ of the two spark dataframes. Store the result in
# dataframe `top10_2000`

# %%
# top10_2000 = TODO:
top10_2000 = top10_2000_f.union(top10_2000_m)
top10_2000.show()
# Out:
# +-----------+-----+---+----+
# |       name|    n|sex|year|
# +-----------+-----+---+----+
# |      Emily|25953|  F|2000|
# |     Hannah|23080|  F|2000|
# |    Madison|19967|  F|2000|
# |     Ashley|17997|  F|2000|
# |      Sarah|17697|  F|2000|
# |     Alexis|17629|  F|2000|
# |   Samantha|17266|  F|2000|
# |    Jessica|15709|  F|2000|
# |  Elizabeth|15094|  F|2000|
# |     Taylor|15078|  F|2000|
# |      Jacob|34471|  M|2000|
# |    Michael|32035|  M|2000|
# |    Matthew|28572|  M|2000|
# |     Joshua|27538|  M|2000|
# |Christopher|24931|  M|2000|
# |   Nicholas|24652|  M|2000|
# |     Andrew|23639|  M|2000|
# |     Joseph|22825|  M|2000|
# |     Daniel|22312|  M|2000|
# |      Tyler|21503|  M|2000|
# +-----------+-----+---+----+

# %% [markdown]
# ### Do it again, complying  with DRY principle

# %%
# TODO:

# %% [markdown]
# Name portfolio through ages
# ===========================
#
# 1. Compute for each year and sex the number of distinct names given that year.

# %%
# nb_names_year_sex = TODO: 

query_portofolio = """ SELECT year, sex, count(name) AS n_distinct
FROM babynames
GROUP BY year, sex
ORDER BY year, sex
"""

# %%
spark.sql(query_portofolio).show(5)
# Out:
# +----+---+----------+
# |year|sex|n_distinct|
# +----+---+----------+
# |1880|  F|       942|
# |1880|  M|      1058|
# |1881|  F|       938|
# |1881|  M|       997|
# |1882|  F|      1028|
# +----+---+----------+
# only showing top 5 rows

# %%
df_sp.groupby(col("year"), col("sex"))\
    .agg(fn.count(col("name")).alias("n_distinct")).show(5)
# Out:
# +----+---+----------+
# |year|sex|n_distinct|
# +----+---+----------+
# |1972|  M|      5750|
# |2004|  F|     18826|
# |1927|  M|      4803|
# |1930|  M|      4541|
# |1882|  F|      1028|
# +----+---+----------+
# only showing top 5 rows

# %%
nb_names_year_sex = df_sp.groupBy([df_sp.year, df_sp.sex])\
                         .count()\
                         .orderBy(col("year"),col("sex"))\
                         .withColumn("year", df_sp.year.cast("int"))

nb_names_year_sex.show(5)
# Out:
# +----+---+-----+
# |year|sex|count|
# +----+---+-----+
# |1880|  F|  942|
# |1880|  M| 1058|
# |1881|  F|  938|
# |1881|  M|  997|
# |1882|  F| 1028|
# +----+---+-----+
# only showing top 5 rows

# %% [markdown]
# 1. Plot the evolution of the number of distinct names as a function of `year`.
# Use some aesthetics to distinguish sexes.

# %%
# TODO:

nb_names_year_sex_pd = nb_names_year_sex.toPandas()

sns.set()
g = sns.lineplot(x = "year",
                 y = "count",
                hue = "sex",
                style = "sex",
                data = nb_names_year_sex_pd)

g.set_title("Number of distinct names with more than 9 occurrences")
plt.ylabel("Number of distinct given names")
plt.show(g)

# %% [markdown]
# Assessing popularity through time
# =================================
#
# 1. For each year and sex, compute the total number of births
# 1. Plot the evolution of the sex ratio over time
# 1. For each year, sex, and name compute the percentage of newborns
# given that name for that given year.
#
#
# > Use `Window` functions.

# %%
# TODO: 

number_birth_4_sex_year = df_sp.dropDuplicates()\
                               .groupBy('year')\
                               .pivot('sex')\
                               .sum('n')\
                               .orderBy('year')
number_birth_4_sex_year.show()
# Out:
# +----+------+------+
# |year|     F|     M|
# +----+------+------+
# |1880| 90993|110491|
# |1881| 91953|100743|
# |1882|107847|113686|
# |1883|112319|104627|
# |1884|129020|114442|
# |1885|133055|107799|
# |1886|144533|110784|
# |1887|145981|101413|
# |1888|178622|120851|
# |1889|178366|110580|
# |1890|190376|111025|
# |1891|185481|101191|
# |1892|212339|122036|
# |1893|212905|112318|
# |1894|222921|115769|
# |1895|233627|117395|
# |1896|237918|119567|
# |1897|234200|112757|
# |1898|258768|122690|
# |1899|233023|106210|
# +----+------+------+
# only showing top 20 rows

# %%
df_sex_ratio = df_sp.select(col("year"),col("sex"),col("n").alias("total"))\
                    .dropDuplicates()\
                    .groupBy("year")\
                    .pivot("sex")\
                    .sum("total")

df_sex_ratio = df_sex_ratio.withColumn("sex_ratio",fn.round(df_sex_ratio.M/df_sex_ratio.F,2))

df_sex_ratio.show()
# Out:
# +----+-------+-------+---------+
# |year|      F|      M|sex_ratio|
# +----+-------+-------+---------+
# |1959|1823703|2023700|     1.11|
# |1896| 202021|  99927|     0.49|
# |1990|1500934|1823214|     1.21|
# |1903| 218947|  98142|     0.45|
# |1884| 107944|  96936|      0.9|
# |1975|1199504|1407900|     1.17|
# |1977|1246494|1471402|     1.18|
# |1888| 150242| 101909|     0.68|
# |1924|1115429|1017735|     0.91|
# |2003|1300395|1636644|     1.26|
# |2007|1332228|1674826|     1.26|
# |1892| 181935| 103388|     0.57|
# |1974|1199758|1423132|     1.19|
# |2015|1205250|1506833|     1.25|
# |1889| 151512|  91798|     0.61|
# |1927|1059989|1011252|     0.95|
# |1955|1769330|1942302|      1.1|
# |1890| 162586|  91395|     0.56|
# |2006|1328930|1654982|     1.25|
# |1978|1232559|1481731|      1.2|
# +----+-------+-------+---------+
# only showing top 20 rows

# %%
# %%
# TODO: plot sex ratio

sns.set()
g = sns.lineplot(x = "year", 
                 y = "sex_ratio",
                 data = df_sex_ratio.toPandas())
g.set_title("Ratio of male births with respect to female births.")
plt.plot(np.linspace(1880, 2020, 141), np.array([.52/.48]*141), 'r-')
plt.ylabel("Sex ratio")
plt.show(g)

# %%

# %% [markdown]
# For each year, sex, and name compute the percentage of newborns given that name for that given year. Use Window functions.

# %%
# TODO: 

window = Window.partitionBy('year','sex')
df_percentage = df_sp\
                  .withColumn('total',fn.sum('n').over(window))\
                  .withColumn('percentage', fn.round((fn.col('n')/fn.sum('n').over(window))*100,2))\
                  .orderBy('year')
df_percentage.show()
# Out:
# +-------+----+---+----+------+----------+
# |   name|   n|sex|year| total|percentage|
# +-------+----+---+----+------+----------+
# |    Joe| 731|  M|1880|110491|      0.66|
# |  Harry|2152|  M|1880|110491|      1.95|
# |  Louis| 828|  M|1880|110491|      0.75|
# | Joseph|2632|  M|1880|110491|      2.38|
# | Edward|2364|  M|1880|110491|      2.14|
# |   Fred|1569|  M|1880|110491|      1.42|
# |  David| 869|  M|1880|110491|      0.79|
# |  James|5927|  M|1880|110491|      5.36|
# |  Frank|3242|  M|1880|110491|      2.93|
# |  Henry|2444|  M|1880|110491|      2.21|
# | Robert|2415|  M|1880|110491|      2.19|
# | Walter|1755|  M|1880|110491|      1.59|
# | Arthur|1599|  M|1880|110491|      1.45|
# | Albert|1493|  M|1880|110491|      1.35|
# | Samuel|1024|  M|1880|110491|      0.93|
# |   John|9655|  M|1880|110491|      8.74|
# |William|9532|  M|1880|110491|      8.63|
# |Charles|5348|  M|1880|110491|      4.84|
# | George|5126|  M|1880|110491|      4.64|
# | Thomas|2534|  M|1880|110491|      2.29|
# +-------+----+---+----+------+----------+
# only showing top 20 rows

# %% [markdown]
# 1. Compute for each year, sex and name  the `row_number`, `rank`, and `dense_rank`
# of the name within that year and sex category, when names are sorted by increasing popularity.

# %%
# TODO:

window = Window.partitionBy('year','sex').orderBy(df_sp.n.asc())
rank = fn.rank().over(window)
dense_rank = fn.dense_rank().over(window)
row_number = fn.row_number().over(window)
df_sp\
    .withColumn('row_number',row_number)\
    .withColumn('rank',rank)\
    .withColumn('dense_rank',dense_rank)\
    .show()
# Out:
# +--------+---+---+----+----------+----+----------+
# |    name|  n|sex|year|row_number|rank|dense_rank|
# +--------+---+---+----+----------+----+----------+
# |   Affie|  5|  F|1882|         1|   1|         1|
# |  Albert|  5|  F|1882|         2|   1|         1|
# |Albertha|  5|  F|1882|         3|   1|         1|
# | Alexina|  5|  F|1882|         4|   1|         1|
# |  Allene|  5|  F|1882|         5|   1|         1|
# |   Altie|  5|  F|1882|         6|   1|         1|
# |  Anabel|  5|  F|1882|         7|   1|         1|
# |    Anie|  5|  F|1882|         8|   1|         1|
# |   Annis|  5|  F|1882|         9|   1|         1|
# | Artelia|  5|  F|1882|        10|   1|         1|
# |  Arthur|  5|  F|1882|        11|   1|         1|
# |    Atha|  5|  F|1882|        12|   1|         1|
# |  Barbra|  5|  F|1882|        13|   1|         1|
# | Beaulah|  5|  F|1882|        14|   1|         1|
# |   Belva|  5|  F|1882|        15|   1|         1|
# |  Berdie|  5|  F|1882|        16|   1|         1|
# | Bertina|  5|  F|1882|        17|   1|         1|
# |  Biddie|  5|  F|1882|        18|   1|         1|
# |Birdella|  5|  F|1882|        19|   1|         1|
# | Blossom|  5|  F|1882|        20|   1|         1|
# +--------+---+---+----+----------+----+----------+
# only showing top 20 rows

# %% [markdown]
# Evolution of top popular names through the century
# ==================================================
#
#
# 1. For each sex, select the ten most popular names in year 2000, and plot the proportion
# of newborns given that name over time. Take into account that some names might have
# zero occurrence during certain years.

# %%
# TODO:
def proptop10_plot(sexe) : 
    if sexe == "female" : name = top10_2000_f.toPandas().name
    if sexe == "male" : name = top10_2000_m.toPandas().name
    name = "','".join(name)
    df_top10 = df_percentage.where("name in ('"+name+"')")
    df_top10_pd = df_top10.toPandas()

    sns.set()
    g = sns.relplot(x = 'year',
                y = 'percentage',
                hue = 'name',
                col = 'sex',
                kind = 'line',
                facet_kws=dict(sharex =True,sharey= False),
                data = df_top10_pd)
    plt.subplots_adjust(top=0.8)
    g.fig.suptitle('Proportion of newborns given top 10 ' + sexe +' name in 2000 over time.')
    
proptop10_plot('female')

# %% [markdown]
# The graphic above is normally intended for women. Nevertheless, we decided to make the men appear because we could see that men were called "Elizabeth" in 1880. Which is quite strange…  (mixed names)

# %% [markdown]
# 1. Use `explain()` to determine the joining strategy used by spark.
#
#
# Plot  the popularity of each of the top ten achievers from year 2000 with respect to time
# ==================================================================================

# %%
# TODO:
proptop10_plot('male')

# %% [markdown]
# Plot the total popularity of the top ten achievers from year 2000 with respect to time
# ==================================================================================

# %%
# %%
# TODO:

# %%

# %% [markdown]
# Plot lorenz curves
# =====================
#
# Every year, the name counts define a discrete probability distribution.
# This distribution, just as income or wealth distribution,
# is (usually) far from being uniform. We want to assess how uneven it is.
# We use the tools developed in econometrics.
#
# Without loss of generality, that we handle a distribution over $1, \ldots, n$
# where $n$ is the number of distinct names given during a year.
# We assume that frequencies $p_1, p_2, \ldots, p_n$ are given in ascending order.
#
# The Lorenz function maps $[0, 1] \to [0, 1]$.
# $$L(x) = \sum_{i=1}^{\lfloor nx \rfloor} p_i$$.
#
# 1. Design a query that adds a column "lorenz" to the dataframe , and for each
# row computes the value of the Lorenz function defined by `year`  and `sex`.

# %%
# TODO:

window = Window.partitionBy('year','sex')
window_lorenz = Window.partitionBy("year","sex").orderBy("percentage").rowsBetween(Window.unboundedPreceding,0)
df_percentage = df_sp\
                  .withColumn('total',fn.sum('n').over(window))\
                  .withColumn('percentage', fn.round((fn.col('n')/fn.sum('n').over(window))*100,2))\
                  .withColumn('lorenz',fn.round(fn.sum('percentage').over(window_lorenz)/100,3))

df_percentage.show(1500)
# Out:
# +-----------+----+---+----+------+----------+------+
# |       name|   n|sex|year| total|percentage|lorenz|
# +-----------+----+---+----+------+----------+------+
# |      Affie|   5|  F|1882|107847|       0.0|   0.0|
# |     Albert|   5|  F|1882|107847|       0.0|   0.0|
# |   Albertha|   5|  F|1882|107847|       0.0|   0.0|
# |    Alexina|   5|  F|1882|107847|       0.0|   0.0|
# |     Allene|   5|  F|1882|107847|       0.0|   0.0|
# |      Altie|   5|  F|1882|107847|       0.0|   0.0|
# |     Anabel|   5|  F|1882|107847|       0.0|   0.0|
# |       Anie|   5|  F|1882|107847|       0.0|   0.0|
# |      Annis|   5|  F|1882|107847|       0.0|   0.0|
# |    Artelia|   5|  F|1882|107847|       0.0|   0.0|
# |     Arthur|   5|  F|1882|107847|       0.0|   0.0|
# |       Atha|   5|  F|1882|107847|       0.0|   0.0|
# |     Barbra|   5|  F|1882|107847|       0.0|   0.0|
# |    Beaulah|   5|  F|1882|107847|       0.0|   0.0|
# |      Belva|   5|  F|1882|107847|       0.0|   0.0|
# |     Berdie|   5|  F|1882|107847|       0.0|   0.0|
# |    Bertina|   5|  F|1882|107847|       0.0|   0.0|
# |     Biddie|   5|  F|1882|107847|       0.0|   0.0|
# |   Birdella|   5|  F|1882|107847|       0.0|   0.0|
# |    Blossom|   5|  F|1882|107847|       0.0|   0.0|
# |       Cara|   5|  F|1882|107847|       0.0|   0.0|
# |    Carmela|   5|  F|1882|107847|       0.0|   0.0|
# |   Carolyne|   5|  F|1882|107847|       0.0|   0.0|
# |    Cathryn|   5|  F|1882|107847|       0.0|   0.0|
# |   Celestia|   5|  F|1882|107847|       0.0|   0.0|
# | Charlottie|   5|  F|1882|107847|       0.0|   0.0|
# |      Cilla|   5|  F|1882|107847|       0.0|   0.0|
# |    Classie|   5|  F|1882|107847|       0.0|   0.0|
# |   Clifford|   5|  F|1882|107847|       0.0|   0.0|
# |   Courtney|   5|  F|1882|107847|       0.0|   0.0|
# |     Daisey|   5|  F|1882|107847|       0.0|   0.0|
# |       Dave|   5|  F|1882|107847|       0.0|   0.0|
# |     Denise|   5|  F|1882|107847|       0.0|   0.0|
# |     Dezzie|   5|  F|1882|107847|       0.0|   0.0|
# |       Dicy|   5|  F|1882|107847|       0.0|   0.0|
# |    Dorthea|   5|  F|1882|107847|       0.0|   0.0|
# |       Dove|   5|  F|1882|107847|       0.0|   0.0|
# |    Edmonia|   5|  F|1882|107847|       0.0|   0.0|
# |     Edward|   5|  F|1882|107847|       0.0|   0.0|
# |     Electa|   5|  F|1882|107847|       0.0|   0.0|
# |   Eleonore|   5|  F|1882|107847|       0.0|   0.0|
# |     Eudora|   5|  F|1882|107847|       0.0|   0.0|
# |      Eulah|   5|  F|1882|107847|       0.0|   0.0|
# |      Fairy|   5|  F|1882|107847|       0.0|   0.0|
# |     Fannye|   5|  F|1882|107847|       0.0|   0.0|
# |    Fidelia|   5|  F|1882|107847|       0.0|   0.0|
# |      Franc|   5|  F|1882|107847|       0.0|   0.0|
# |   Francina|   5|  F|1882|107847|       0.0|   0.0|
# |  Francisca|   5|  F|1882|107847|       0.0|   0.0|
# | Fredericka|   5|  F|1882|107847|       0.0|   0.0|
# |    Genevra|   5|  F|1882|107847|       0.0|   0.0|
# |     Grayce|   5|  F|1882|107847|       0.0|   0.0|
# |      Helga|   5|  F|1882|107847|       0.0|   0.0|
# |     Hessie|   5|  F|1882|107847|       0.0|   0.0|
# |     Honora|   5|  F|1882|107847|       0.0|   0.0|
# |       Iris|   5|  F|1882|107847|       0.0|   0.0|
# |        Iza|   5|  F|1882|107847|       0.0|   0.0|
# |   Jeanetta|   5|  F|1882|107847|       0.0|   0.0|
# |    Jeannie|   5|  F|1882|107847|       0.0|   0.0|
# |     Jemima|   5|  F|1882|107847|       0.0|   0.0|
# |    Jerusha|   5|  F|1882|107847|       0.0|   0.0|
# |      Jesse|   5|  F|1882|107847|       0.0|   0.0|
# |     Jewell|   5|  F|1882|107847|       0.0|   0.0|
# |     Joella|   5|  F|1882|107847|       0.0|   0.0|
# |       Judy|   5|  F|1882|107847|       0.0|   0.0|
# |      Junie|   5|  F|1882|107847|       0.0|   0.0|
# |  Katharina|   5|  F|1882|107847|       0.0|   0.0|
# |       Katy|   5|  F|1882|107847|       0.0|   0.0|
# |     Laurie|   5|  F|1882|107847|       0.0|   0.0|
# |    Lavenia|   5|  F|1882|107847|       0.0|   0.0|
# |     Leatha|   5|  F|1882|107847|       0.0|   0.0|
# |       Leda|   5|  F|1882|107847|       0.0|   0.0|
# |    Lisette|   5|  F|1882|107847|       0.0|   0.0|
# |     Littie|   5|  F|1882|107847|       0.0|   0.0|
# |       Loda|   5|  F|1882|107847|       0.0|   0.0|
# |    Lorenza|   5|  F|1882|107847|       0.0|   0.0|
# |    Louetta|   5|  F|1882|107847|       0.0|   0.0|
# |   Louvenia|   5|  F|1882|107847|       0.0|   0.0|
# |       Luda|   5|  F|1882|107847|       0.0|   0.0|
# |      Lular|   5|  F|1882|107847|       0.0|   0.0|
# |      Lynda|   5|  F|1882|107847|       0.0|   0.0|
# |  Margarett|   5|  F|1882|107847|       0.0|   0.0|
# |   Margeret|   5|  F|1882|107847|       0.0|   0.0|
# |     Marget|   5|  F|1882|107847|       0.0|   0.0|
# |     Mariam|   5|  F|1882|107847|       0.0|   0.0|
# |       Maye|   5|  F|1882|107847|       0.0|   0.0|
# |      Minda|   5|  F|1882|107847|       0.0|   0.0|
# |    Miranda|   5|  F|1882|107847|       0.0|   0.0|
# |     Modena|   5|  F|1882|107847|       0.0|   0.0|
# |      Nanna|   5|  F|1882|107847|       0.0|   0.0|
# |     Nealie|   5|  F|1882|107847|       0.0|   0.0|
# |      Nelie|   5|  F|1882|107847|       0.0|   0.0|
# |      Olena|   5|  F|1882|107847|       0.0|   0.0|
# |       Olie|   5|  F|1882|107847|       0.0|   0.0|
# |     Otelia|   5|  F|1882|107847|       0.0|   0.0|
# |      Penny|   5|  F|1882|107847|       0.0|   0.0|
# |     Pheobe|   5|  F|1882|107847|       0.0|   0.0|
# |     Pollie|   5|  F|1882|107847|       0.0|   0.0|
# |     Portia|   5|  F|1882|107847|       0.0|   0.0|
# |      Rella|   5|  F|1882|107847|       0.0|   0.0|
# |     Rennie|   5|  F|1882|107847|       0.0|   0.0|
# |   Roseanna|   5|  F|1882|107847|       0.0|   0.0|
# |     Roxana|   5|  F|1882|107847|       0.0|   0.0|
# |     Sabina|   5|  F|1882|107847|       0.0|   0.0|
# |       Sada|   5|  F|1882|107847|       0.0|   0.0|
# |      Sadye|   5|  F|1882|107847|       0.0|   0.0|
# |     Sammie|   5|  F|1882|107847|       0.0|   0.0|
# |    Savilla|   5|  F|1882|107847|       0.0|   0.0|
# |     Selena|   5|  F|1882|107847|       0.0|   0.0|
# |    Shellie|   5|  F|1882|107847|       0.0|   0.0|
# |     Sibbie|   5|  F|1882|107847|       0.0|   0.0|
# |     Thekla|   5|  F|1882|107847|       0.0|   0.0|
# |      Tinie|   5|  F|1882|107847|       0.0|   0.0|
# |       Veda|   5|  F|1882|107847|       0.0|   0.0|
# |     Vienna|   5|  F|1882|107847|       0.0|   0.0|
# |      Vinia|   5|  F|1882|107847|       0.0|   0.0|
# |       Vira|   5|  F|1882|107847|       0.0|   0.0|
# |     Willia|   5|  F|1882|107847|       0.0|   0.0|
# |     Zaidee|   5|  F|1882|107847|       0.0|   0.0|
# |       Zana|   5|  F|1882|107847|       0.0|   0.0|
# |      Zilla|   5|  F|1882|107847|       0.0|   0.0|
# |    Adaline|  16|  F|1882|107847|      0.01|   0.0|
# |      Bella|  16|  F|1882|107847|      0.01|   0.0|
# |    Clemmie|  16|  F|1882|107847|      0.01|   0.0|
# |     Corrie|  16|  F|1882|107847|      0.01|   0.0|
# |      Doris|  16|  F|1882|107847|      0.01| 0.001|
# |      Eddie|  16|  F|1882|107847|      0.01| 0.001|
# |      Hilma|  16|  F|1882|107847|      0.01| 0.001|
# |   Hortense|  16|  F|1882|107847|      0.01| 0.001|
# |      India|  16|  F|1882|107847|      0.01| 0.001|
# |       Iola|  16|  F|1882|107847|      0.01| 0.001|
# |      Jenny|  16|  F|1882|107847|      0.01| 0.001|
# |     Liddie|  16|  F|1882|107847|      0.01| 0.001|
# |       Liza|  16|  F|1882|107847|      0.01| 0.001|
# |      Matie|  16|  F|1882|107847|      0.01| 0.001|
# |     Mellie|  16|  F|1882|107847|      0.01| 0.002|
# |      Minta|  16|  F|1882|107847|      0.01| 0.002|
# |       Vada|  16|  F|1882|107847|      0.01| 0.002|
# |    Arminta|  15|  F|1882|107847|      0.01| 0.002|
# |    Deborah|  15|  F|1882|107847|      0.01| 0.002|
# |   Dorothea|  15|  F|1882|107847|      0.01| 0.002|
# |    Ethelyn|  15|  F|1882|107847|      0.01| 0.002|
# |       Ione|  15|  F|1882|107847|      0.01| 0.002|
# |     Jettie|  15|  F|1882|107847|      0.01| 0.002|
# |     Joanna|  15|  F|1882|107847|      0.01| 0.002|
# |        Joe|  15|  F|1882|107847|      0.01| 0.003|
# |       Leta|  15|  F|1882|107847|      0.01| 0.003|
# |     Libbie|  15|  F|1882|107847|      0.01| 0.003|
# |    Luvenia|  15|  F|1882|107847|      0.01| 0.003|
# |     Muriel|  15|  F|1882|107847|      0.01| 0.003|
# |    Natalie|  15|  F|1882|107847|      0.01| 0.003|
# |        Ray|  15|  F|1882|107847|      0.01| 0.003|
# |    Rosanna|  15|  F|1882|107847|      0.01| 0.003|
# |   Samantha|  15|  F|1882|107847|      0.01| 0.003|
# |      Tilda|  15|  F|1882|107847|      0.01| 0.003|
# |      Willa|  15|  F|1882|107847|      0.01| 0.004|
# |    Abigail|  14|  F|1882|107847|      0.01| 0.004|
# |    Arvilla|  14|  F|1882|107847|      0.01| 0.004|
# |  Christena|  14|  F|1882|107847|      0.01| 0.004|
# |      Harry|  14|  F|1882|107847|      0.01| 0.004|
# |      Lenna|  14|  F|1882|107847|      0.01| 0.004|
# |     Lissie|  14|  F|1882|107847|      0.01| 0.004|
# |      Lutie|  14|  F|1882|107847|      0.01| 0.004|
# |   Mathilde|  14|  F|1882|107847|      0.01| 0.004|
# |     Serena|  14|  F|1882|107847|      0.01| 0.004|
# |  Sophronia|  14|  F|1882|107847|      0.01| 0.005|
# |     Tempie|  14|  F|1882|107847|      0.01| 0.005|
# |      Verda|  14|  F|1882|107847|      0.01| 0.005|
# |     Vernie|  14|  F|1882|107847|      0.01| 0.005|
# |      Wilma|  14|  F|1882|107847|      0.01| 0.005|
# |      Aimee|  13|  F|1882|107847|      0.01| 0.005|
# |       Alva|  13|  F|1882|107847|      0.01| 0.005|
# |    America|  13|  F|1882|107847|      0.01| 0.005|
# |    Arizona|  13|  F|1882|107847|      0.01| 0.005|
# |       Aura|  13|  F|1882|107847|      0.01| 0.005|
# |   Cathrine|  13|  F|1882|107847|      0.01| 0.006|
# |   Clarissa|  13|  F|1882|107847|      0.01| 0.006|
# |     Connie|  13|  F|1882|107847|      0.01| 0.006|
# |       Dena|  13|  F|1882|107847|      0.01| 0.006|
# |    Emeline|  13|  F|1882|107847|      0.01| 0.006|
# |      Emmer|  13|  F|1882|107847|      0.01| 0.006|
# |     Evalyn|  13|  F|1882|107847|      0.01| 0.006|
# |       Inga|  13|  F|1882|107847|      0.01| 0.006|
# |     Lonnie|  13|  F|1882|107847|      0.01| 0.006|
# |    Malvina|  13|  F|1882|107847|      0.01| 0.006|
# |     Mintie|  13|  F|1882|107847|      0.01| 0.007|
# |      Norah|  13|  F|1882|107847|      0.01| 0.007|
# |       Ocie|  13|  F|1882|107847|      0.01| 0.007|
# |       Opal|  13|  F|1882|107847|      0.01| 0.007|
# |     Rowena|  13|  F|1882|107847|      0.01| 0.007|
# |   Theresia|  13|  F|1882|107847|      0.01| 0.007|
# |    Tressie|  13|  F|1882|107847|      0.01| 0.007|
# |       Vena|  13|  F|1882|107847|      0.01| 0.007|
# |      Besse|  12|  F|1882|107847|      0.01| 0.007|
# |    Camilla|  12|  F|1882|107847|      0.01| 0.007|
# |     Corine|  12|  F|1882|107847|      0.01| 0.008|
# |        Dee|  12|  F|1882|107847|      0.01| 0.008|
# |     Dorcas|  12|  F|1882|107847|      0.01| 0.008|
# |     Easter|  12|  F|1882|107847|      0.01| 0.008|
# |       Elda|  12|  F|1882|107847|      0.01| 0.008|
# |  Elizebeth|  12|  F|1882|107847|      0.01| 0.008|
# |     Eloise|  12|  F|1882|107847|      0.01| 0.008|
# |       Erna|  12|  F|1882|107847|      0.01| 0.008|
# |       Etna|  12|  F|1882|107847|      0.01| 0.008|
# |    Eugenie|  12|  F|1882|107847|      0.01| 0.008|
# |       Gena|  12|  F|1882|107847|      0.01| 0.009|
# |  Geraldine|  12|  F|1882|107847|      0.01| 0.009|
# |     Hedwig|  12|  F|1882|107847|      0.01| 0.009|
# |     Huldah|  12|  F|1882|107847|      0.01| 0.009|
# |     Idella|  12|  F|1882|107847|      0.01| 0.009|
# |    Imogene|  12|  F|1882|107847|      0.01| 0.009|
# |        Isa|  12|  F|1882|107847|      0.01| 0.009|
# |     Jeanne|  12|  F|1882|107847|      0.01| 0.009|
# |   Lauretta|  12|  F|1882|107847|      0.01| 0.009|
# |      Loula|  12|  F|1882|107847|      0.01| 0.009|
# |  Magdalene|  12|  F|1882|107847|      0.01|  0.01|
# |     Mallie|  12|  F|1882|107847|      0.01|  0.01|
# |       Mame|  12|  F|1882|107847|      0.01|  0.01|
# |    Margery|  12|  F|1882|107847|      0.01|  0.01|
# |       Onie|  12|  F|1882|107847|      0.01|  0.01|
# |     Robert|  12|  F|1882|107847|      0.01|  0.01|
# |    Suzanne|  12|  F|1882|107847|      0.01|  0.01|
# |     Thomas|  12|  F|1882|107847|      0.01|  0.01|
# |       Abby|  11|  F|1882|107847|      0.01|  0.01|
# |     Althea|  11|  F|1882|107847|      0.01|  0.01|
# |     Amalia|  11|  F|1882|107847|      0.01| 0.011|
# |  Anastasia|  11|  F|1882|107847|      0.01| 0.011|
# |   Angelina|  11|  F|1882|107847|      0.01| 0.011|
# |    Annetta|  11|  F|1882|107847|      0.01| 0.011|
# |       Arie|  11|  F|1882|107847|      0.01| 0.011|
# |      Arrie|  11|  F|1882|107847|      0.01| 0.011|
# |      Beryl|  11|  F|1882|107847|      0.01| 0.011|
# |    Claudie|  11|  F|1882|107847|      0.01| 0.011|
# |      Corda|  11|  F|1882|107847|      0.01| 0.011|
# |     Cordia|  11|  F|1882|107847|      0.01| 0.011|
# |      Dicie|  11|  F|1882|107847|      0.01| 0.012|
# |      Docia|  11|  F|1882|107847|      0.01| 0.012|
# |      Donie|  11|  F|1882|107847|      0.01| 0.012|
# |   Eleanora|  11|  F|1882|107847|      0.01| 0.012|
# |     Emelie|  11|  F|1882|107847|      0.01| 0.012|
# |      Emmie|  11|  F|1882|107847|      0.01| 0.012|
# |    Florida|  11|  F|1882|107847|      0.01| 0.012|
# |      Frank|  11|  F|1882|107847|      0.01| 0.012|
# |      Irena|  11|  F|1882|107847|      0.01| 0.012|
# |       Ivah|  11|  F|1882|107847|      0.01| 0.012|
# |       Joan|  11|  F|1882|107847|      0.01| 0.013|
# | Josiephine|  11|  F|1882|107847|      0.01| 0.013|
# |      Lelah|  11|  F|1882|107847|      0.01| 0.013|
# |      Leone|  11|  F|1882|107847|      0.01| 0.013|
# |      Lovie|  11|  F|1882|107847|      0.01| 0.013|
# |      Madie|  11|  F|1882|107847|      0.01| 0.013|
# |      Manda|  11|  F|1882|107847|      0.01| 0.013|
# |      Merle|  11|  F|1882|107847|      0.01| 0.013|
# |       Mona|  11|  F|1882|107847|      0.01| 0.013|
# |      Nella|  11|  F|1882|107847|      0.01| 0.013|
# |      Pansy|  11|  F|1882|107847|      0.01| 0.014|
# |      Queen|  11|  F|1882|107847|      0.01| 0.014|
# |    Queenie|  11|  F|1882|107847|      0.01| 0.014|
# |      Sybil|  11|  F|1882|107847|      0.01| 0.014|
# |    Annabel|  10|  F|1882|107847|      0.01| 0.014|
# |        Ara|  10|  F|1882|107847|      0.01| 0.014|
# |      Attie|  10|  F|1882|107847|      0.01| 0.014|
# |       Bird|  10|  F|1882|107847|      0.01| 0.014|
# |      Bulah|  10|  F|1882|107847|      0.01| 0.014|
# |   Carolina|  10|  F|1882|107847|      0.01| 0.014|
# |    Delilah|  10|  F|1882|107847|      0.01| 0.015|
# |       Dell|  10|  F|1882|107847|      0.01| 0.015|
# |     Dellar|  10|  F|1882|107847|      0.01| 0.015|
# |   Delphine|  10|  F|1882|107847|      0.01| 0.015|
# |    Dolores|  10|  F|1882|107847|      0.01| 0.015|
# |     Dottie|  10|  F|1882|107847|      0.01| 0.015|
# |      Edyth|  10|  F|1882|107847|      0.01| 0.015|
# |     Elinor|  10|  F|1882|107847|      0.01| 0.015|
# |       Esta|  10|  F|1882|107847|      0.01| 0.015|
# |      Ester|  10|  F|1882|107847|      0.01| 0.015|
# |      Genie|  10|  F|1882|107847|      0.01| 0.016|
# |   Gretchen|  10|  F|1882|107847|      0.01| 0.016|
# |    Hermina|  10|  F|1882|107847|      0.01| 0.016|
# |        Icy|  10|  F|1882|107847|      0.01| 0.016|
# |      Jewel|  10|  F|1882|107847|      0.01| 0.016|
# |     Josefa|  10|  F|1882|107847|      0.01| 0.016|
# |   Katheryn|  10|  F|1882|107847|      0.01| 0.016|
# |     Leanna|  10|  F|1882|107847|      0.01| 0.016|
# |       Loma|  10|  F|1882|107847|      0.01| 0.016|
# |     Marcia|  10|  F|1882|107847|      0.01| 0.016|
# |    Marinda|  10|  F|1882|107847|      0.01| 0.017|
# |    Melinda|  10|  F|1882|107847|      0.01| 0.017|
# |      Metta|  10|  F|1882|107847|      0.01| 0.017|
# |      Nelly|  10|  F|1882|107847|      0.01| 0.017|
# |     Odessa|  10|  F|1882|107847|      0.01| 0.017|
# |       Odie|  10|  F|1882|107847|      0.01| 0.017|
# |  Philomena|  10|  F|1882|107847|      0.01| 0.017|
# |       Sula|  10|  F|1882|107847|      0.01| 0.017|
# |  Tennessee|  10|  F|1882|107847|      0.01| 0.017|
# |       Theo|  10|  F|1882|107847|      0.01| 0.017|
# |     Tressa|  10|  F|1882|107847|      0.01| 0.018|
# |      Wanda|  10|  F|1882|107847|      0.01| 0.018|
# |      Aline|   9|  F|1882|107847|      0.01| 0.018|
# |       Amie|   9|  F|1882|107847|      0.01| 0.018|
# |       Avis|   9|  F|1882|107847|      0.01| 0.018|
# |    Celeste|   9|  F|1882|107847|      0.01| 0.018|
# |     Cordie|   9|  F|1882|107847|      0.01| 0.018|
# |      Dosha|   9|  F|1882|107847|      0.01| 0.018|
# |      Eller|   9|  F|1882|107847|      0.01| 0.018|
# |     Elvina|   9|  F|1882|107847|      0.01| 0.018|
# |      Ethyl|   9|  F|1882|107847|      0.01| 0.019|
# |    Eulalia|   9|  F|1882|107847|      0.01| 0.019|
# | Evangeline|   9|  F|1882|107847|      0.01| 0.019|
# |      Faith|   9|  F|1882|107847|      0.01| 0.019|
# |    Felicia|   9|  F|1882|107847|      0.01| 0.019|
# |   Florance|   9|  F|1882|107847|      0.01| 0.019|
# |       Fred|   9|  F|1882|107847|      0.01| 0.019|
# |      Frona|   9|  F|1882|107847|      0.01| 0.019|
# |    Glennie|   9|  F|1882|107847|      0.01| 0.019|
# |     Hassie|   9|  F|1882|107847|      0.01| 0.019|
# |  Henriette|   9|  F|1882|107847|      0.01|  0.02|
# |      Hetty|   9|  F|1882|107847|      0.01|  0.02|
# |    Isadora|   9|  F|1882|107847|      0.01|  0.02|
# |   Juliette|   9|  F|1882|107847|      0.01|  0.02|
# |   Kathryne|   9|  F|1882|107847|      0.01|  0.02|
# |     Kizzie|   9|  F|1882|107847|      0.01|  0.02|
# |     Lavada|   9|  F|1882|107847|      0.01|  0.02|
# |     Leslie|   9|  F|1882|107847|      0.01|  0.02|
# |     Luetta|   9|  F|1882|107847|      0.01|  0.02|
# |      Nanie|   9|  F|1882|107847|      0.01|  0.02|
# |       Nena|   9|  F|1882|107847|      0.01| 0.021|
# |      Nonie|   9|  F|1882|107847|      0.01| 0.021|
# |      Ottie|   9|  F|1882|107847|      0.01| 0.021|
# |    Paulina|   9|  F|1882|107847|      0.01| 0.021|
# |     Pennie|   9|  F|1882|107847|      0.01| 0.021|
# |      Petra|   9|  F|1882|107847|      0.01| 0.021|
# |       Reba|   9|  F|1882|107847|      0.01| 0.021|
# |   Rosemary|   9|  F|1882|107847|      0.01| 0.021|
# |    Shirley|   9|  F|1882|107847|      0.01| 0.021|
# |     Sidney|   9|  F|1882|107847|      0.01| 0.021|
# |     Ursula|   9|  F|1882|107847|      0.01| 0.021|
# |     Vallie|   9|  F|1882|107847|      0.01| 0.022|
# |       Viva|   9|  F|1882|107847|      0.01| 0.022|
# |     Winona|   9|  F|1882|107847|      0.01| 0.022|
# |       Zada|   9|  F|1882|107847|      0.01| 0.022|
# |       Zola|   9|  F|1882|107847|      0.01| 0.022|
# |      Audie|   8|  F|1882|107847|      0.01| 0.022|
# |  Augustine|   8|  F|1882|107847|      0.01| 0.022|
# |     Aurora|   8|  F|1882|107847|      0.01| 0.022|
# |     Beckie|   8|  F|1882|107847|      0.01| 0.022|
# |       Buna|   8|  F|1882|107847|      0.01| 0.022|
# |   Caldonia|   8|  F|1882|107847|      0.01| 0.023|
# |      Calla|   8|  F|1882|107847|      0.01| 0.023|
# |    Candace|   8|  F|1882|107847|      0.01| 0.023|
# |   Carlotta|   8|  F|1882|107847|      0.01| 0.023|
# |    Clarice|   8|  F|1882|107847|      0.01| 0.023|
# |     Claude|   8|  F|1882|107847|      0.01| 0.023|
# |    Corrine|   8|  F|1882|107847|      0.01| 0.023|
# |      Crete|   8|  F|1882|107847|      0.01| 0.023|
# |      Dessa|   8|  F|1882|107847|      0.01| 0.023|
# |      Diana|   8|  F|1882|107847|      0.01| 0.023|
# |      Dinah|   8|  F|1882|107847|      0.01| 0.024|
# |       Edla|   8|  F|1882|107847|      0.01| 0.024|
# |   Eleonora|   8|  F|1882|107847|      0.01| 0.024|
# |   Elfrieda|   8|  F|1882|107847|      0.01| 0.024|
# |      Elisa|   8|  F|1882|107847|      0.01| 0.024|
# |     Elmina|   8|  F|1882|107847|      0.01| 0.024|
# |       Elta|   8|  F|1882|107847|      0.01| 0.024|
# |      Elvie|   8|  F|1882|107847|      0.01| 0.024|
# |     Emilia|   8|  F|1882|107847|      0.01| 0.024|
# |     Estell|   8|  F|1882|107847|      0.01| 0.024|
# |    Evaline|   8|  F|1882|107847|      0.01| 0.025|
# |    Eveline|   8|  F|1882|107847|      0.01| 0.025|
# |    Florrie|   8|  F|1882|107847|      0.01| 0.025|
# |     Fronia|   8|  F|1882|107847|      0.01| 0.025|
# |       Gail|   8|  F|1882|107847|      0.01| 0.025|
# |        Ira|   8|  F|1882|107847|      0.01| 0.025|
# |      Izora|   8|  F|1882|107847|      0.01| 0.025|
# |    Jessica|   8|  F|1882|107847|      0.01| 0.025|
# |      Jodie|   8|  F|1882|107847|      0.01| 0.025|
# |   Johannah|   8|  F|1882|107847|      0.01| 0.025|
# |     Judith|   8|  F|1882|107847|      0.01| 0.026|
# |     Kattie|   8|  F|1882|107847|      0.01| 0.026|
# |      Luisa|   8|  F|1882|107847|      0.01| 0.026|
# |    Manuela|   8|  F|1882|107847|      0.01| 0.026|
# |     Mettie|   8|  F|1882|107847|      0.01| 0.026|
# |     Myrtis|   8|  F|1882|107847|      0.01| 0.026|
# |      Nelia|   8|  F|1882|107847|      0.01| 0.026|
# |       Nita|   8|  F|1882|107847|      0.01| 0.026|
# |        Osa|   8|  F|1882|107847|      0.01| 0.026|
# |        Ova|   8|  F|1882|107847|      0.01| 0.026|
# |    Paralee|   8|  F|1882|107847|      0.01| 0.027|
# |  Parthenia|   8|  F|1882|107847|      0.01| 0.027|
# |    Phyllis|   8|  F|1882|107847|      0.01| 0.027|
# |    Rachael|   8|  F|1882|107847|      0.01| 0.027|
# |     Rettie|   8|  F|1882|107847|      0.01| 0.027|
# |    Rosalia|   8|  F|1882|107847|      0.01| 0.027|
# |      Rosia|   8|  F|1882|107847|      0.01| 0.027|
# |     Rosina|   8|  F|1882|107847|      0.01| 0.027|
# |    Roxanna|   8|  F|1882|107847|      0.01| 0.027|
# |  Theodosia|   8|  F|1882|107847|      0.01| 0.027|
# |       Tiny|   8|  F|1882|107847|      0.01| 0.028|
# |     Tommie|   8|  F|1882|107847|      0.01| 0.028|
# |     Trudie|   8|  F|1882|107847|      0.01| 0.028|
# |     Verona|   8|  F|1882|107847|      0.01| 0.028|
# |     Vertie|   8|  F|1882|107847|      0.01| 0.028|
# | Wilhelmine|   8|  F|1882|107847|      0.01| 0.028|
# |        Zoa|   8|  F|1882|107847|      0.01| 0.028|
# |     Agusta|   7|  F|1882|107847|      0.01| 0.028|
# |     Albina|   7|  F|1882|107847|      0.01| 0.028|
# |     Alicia|   7|  F|1882|107847|      0.01| 0.028|
# |     Almira|   7|  F|1882|107847|      0.01| 0.029|
# | Alphonsine|   7|  F|1882|107847|      0.01| 0.029|
# |     Alvena|   7|  F|1882|107847|      0.01| 0.029|
# |        Ana|   7|  F|1882|107847|      0.01| 0.029|
# |    Ardella|   7|  F|1882|107847|      0.01| 0.029|
# |     Audrey|   7|  F|1882|107847|      0.01| 0.029|
# |     Bennie|   7|  F|1882|107847|      0.01| 0.029|
# |    Camille|   7|  F|1882|107847|      0.01| 0.029|
# |     Cammie|   7|  F|1882|107847|      0.01| 0.029|
# |     Carmen|   7|  F|1882|107847|      0.01| 0.029|
# |       Cary|   7|  F|1882|107847|      0.01|  0.03|
# |  Celestine|   7|  F|1882|107847|      0.01|  0.03|
# |     Celina|   7|  F|1882|107847|      0.01|  0.03|
# |     Cherry|   7|  F|1882|107847|      0.01|  0.03|
# |   Christie|   7|  F|1882|107847|      0.01|  0.03|
# |      Coral|   7|  F|1882|107847|      0.01|  0.03|
# |     Dellie|   7|  F|1882|107847|      0.01|  0.03|
# |     Delpha|   7|  F|1882|107847|      0.01|  0.03|
# |    Delphia|   7|  F|1882|107847|      0.01|  0.03|
# |       Effa|   7|  F|1882|107847|      0.01|  0.03|
# |   Eleanore|   7|  F|1882|107847|      0.01| 0.031|
# |        Era|   7|  F|1882|107847|      0.01| 0.031|
# |    Evelina|   7|  F|1882|107847|      0.01| 0.031|
# |       Exie|   7|  F|1882|107847|      0.01| 0.031|
# |       Gene|   7|  F|1882|107847|      0.01| 0.031|
# |   Georgina|   7|  F|1882|107847|      0.01| 0.031|
# |      Golda|   7|  F|1882|107847|      0.01| 0.031|
# |  Guadalupe|   7|  F|1882|107847|      0.01| 0.031|
# |     Jeffie|   7|  F|1882|107847|      0.01| 0.031|
# |     Jinnie|   7|  F|1882|107847|      0.01| 0.031|
# |      Joyce|   7|  F|1882|107847|      0.01| 0.032|
# |      Juana|   7|  F|1882|107847|      0.01| 0.032|
# |     Juliet|   7|  F|1882|107847|      0.01| 0.032|
# |    Kathyrn|   7|  F|1882|107847|      0.01| 0.032|
# |      Letta|   7|  F|1882|107847|      0.01| 0.032|
# |     Levina|   7|  F|1882|107847|      0.01| 0.032|
# |     Lollie|   7|  F|1882|107847|      0.01| 0.032|
# |    Loretto|   7|  F|1882|107847|      0.01| 0.032|
# |    Lucindy|   7|  F|1882|107847|      0.01| 0.032|
# |   Magdalen|   7|  F|1882|107847|      0.01| 0.032|
# |   Magnolia|   7|  F|1882|107847|      0.01| 0.033|
# |    Malissa|   7|  F|1882|107847|      0.01| 0.033|
# |      Manie|   7|  F|1882|107847|      0.01| 0.033|
# |     Mannie|   7|  F|1882|107847|      0.01| 0.033|
# |    Marilla|   7|  F|1882|107847|      0.01| 0.033|
# |    Maybell|   7|  F|1882|107847|      0.01| 0.033|
# |     Maymie|   7|  F|1882|107847|      0.01| 0.033|
# |   Mercedes|   7|  F|1882|107847|      0.01| 0.033|
# |      Mercy|   7|  F|1882|107847|      0.01| 0.033|
# |       Mima|   7|  F|1882|107847|      0.01| 0.033|
# |      Odile|   7|  F|1882|107847|      0.01| 0.034|
# |       Orah|   7|  F|1882|107847|      0.01| 0.034|
# |       Osie|   7|  F|1882|107847|      0.01| 0.034|
# |   Prudence|   7|  F|1882|107847|      0.01| 0.034|
# |     Prudie|   7|  F|1882|107847|      0.01| 0.034|
# |       Rhea|   7|  F|1882|107847|      0.01| 0.034|
# |      Rinda|   7|  F|1882|107847|      0.01| 0.034|
# |     Rosena|   7|  F|1882|107847|      0.01| 0.034|
# |       Rosy|   7|  F|1882|107847|      0.01| 0.034|
# |       Roxy|   7|  F|1882|107847|      0.01| 0.034|
# |     Sarrah|   7|  F|1882|107847|      0.01| 0.035|
# |   Susannah|   7|  F|1882|107847|      0.01| 0.035|
# |       Thea|   7|  F|1882|107847|      0.01| 0.035|
# |       Tula|   7|  F|1882|107847|      0.01| 0.035|
# |        Ula|   7|  F|1882|107847|      0.01| 0.035|
# |     Walter|   7|  F|1882|107847|      0.01| 0.035|
# |       Will|   7|  F|1882|107847|      0.01| 0.035|
# |      Zadie|   7|  F|1882|107847|      0.01| 0.035|
# |    Zenobia|   7|  F|1882|107847|      0.01| 0.035|
# |      Zetta|   7|  F|1882|107847|      0.01| 0.035|
# |  Albertina|   6|  F|1882|107847|      0.01| 0.036|
# |       Alda|   6|  F|1882|107847|      0.01| 0.036|
# |     Alwina|   6|  F|1882|107847|      0.01| 0.036|
# |      Alyce|   6|  F|1882|107847|      0.01| 0.036|
# |   Annabell|   6|  F|1882|107847|      0.01| 0.036|
# |       Arah|   6|  F|1882|107847|      0.01| 0.036|
# |    Arminda|   6|  F|1882|107847|      0.01| 0.036|
# |       Bama|   6|  F|1882|107847|      0.01| 0.036|
# | Bernadette|   6|  F|1882|107847|      0.01| 0.036|
# |  Bernadine|   6|  F|1882|107847|      0.01| 0.036|
# |     Birtie|   6|  F|1882|107847|      0.01| 0.037|
# |      Buena|   6|  F|1882|107847|      0.01| 0.037|
# |     Byrdie|   6|  F|1882|107847|      0.01| 0.037|
# |   Capitola|   6|  F|1882|107847|      0.01| 0.037|
# |      Carol|   6|  F|1882|107847|      0.01| 0.037|
# |    Cathern|   6|  F|1882|107847|      0.01| 0.037|
# |    Charlie|   6|  F|1882|107847|      0.01| 0.037|
# | Christiana|   6|  F|1882|107847|      0.01| 0.037|
# |   Claribel|   6|  F|1882|107847|      0.01| 0.037|
# |   Claudine|   6|  F|1882|107847|      0.01| 0.037|
# |      Clora|   6|  F|1882|107847|      0.01| 0.038|
# |   Columbia|   6|  F|1882|107847|      0.01| 0.038|
# |       Dana|   6|  F|1882|107847|      0.01| 0.038|
# |     Delila|   6|  F|1882|107847|      0.01| 0.038|
# |     Dillie|   6|  F|1882|107847|      0.01| 0.038|
# |     Doshie|   6|  F|1882|107847|      0.01| 0.038|
# |   Drucilla|   6|  F|1882|107847|      0.01| 0.038|
# |     Eileen|   6|  F|1882|107847|      0.01| 0.038|
# |   Elizbeth|   6|  F|1882|107847|      0.01| 0.038|
# |       Etha|   6|  F|1882|107847|      0.01| 0.038|
# |       Eura|   6|  F|1882|107847|      0.01| 0.039|
# |    Evalena|   6|  F|1882|107847|      0.01| 0.039|
# |        Eve|   6|  F|1882|107847|      0.01| 0.039|
# |     Fronie|   6|  F|1882|107847|      0.01| 0.039|
# |     Glenna|   6|  F|1882|107847|      0.01| 0.039|
# |     Hennie|   6|  F|1882|107847|      0.01| 0.039|
# |   Henretta|   6|  F|1882|107847|      0.01| 0.039|
# |    Hermine|   6|  F|1882|107847|      0.01| 0.039|
# |       Hope|   6|  F|1882|107847|      0.01| 0.039|
# |       Ivie|   6|  F|1882|107847|      0.01| 0.039|
# |     Jeanie|   6|  F|1882|107847|      0.01|  0.04|
# |     Joseph|   6|  F|1882|107847|      0.01|  0.04|
# |     Jossie|   6|  F|1882|107847|      0.01|  0.04|
# |    Justina|   6|  F|1882|107847|      0.01|  0.04|
# |        Lea|   6|  F|1882|107847|      0.01|  0.04|
# |     Leaner|   6|  F|1882|107847|      0.01|  0.04|
# |      Lemma|   6|  F|1882|107847|      0.01|  0.04|
# |     Leonia|   6|  F|1882|107847|      0.01|  0.04|
# |   Lorraine|   6|  F|1882|107847|      0.01|  0.04|
# |       Lota|   6|  F|1882|107847|      0.01|  0.04|
# |      Louis|   6|  F|1882|107847|      0.01| 0.041|
# |    Lucetta|   6|  F|1882|107847|      0.01| 0.041|
# |      Macie|   6|  F|1882|107847|      0.01| 0.041|
# |    Mahalie|   6|  F|1882|107847|      0.01| 0.041|
# | Margaretta|   6|  F|1882|107847|      0.01| 0.041|
# |      Marry|   6|  F|1882|107847|      0.01| 0.041|
# |    Martina|   6|  F|1882|107847|      0.01| 0.041|
# |    Maryann|   6|  F|1882|107847|      0.01| 0.041|
# |  Millicent|   6|  F|1882|107847|      0.01| 0.041|
# |  Narcissus|   6|  F|1882|107847|      0.01| 0.041|
# |      Netta|   6|  F|1882|107847|      0.01| 0.042|
# |    Novella|   6|  F|1882|107847|      0.01| 0.042|
# |        Oda|   6|  F|1882|107847|      0.01| 0.042|
# |     Odelia|   6|  F|1882|107847|      0.01| 0.042|
# |     Olevia|   6|  F|1882|107847|      0.01| 0.042|
# |        Ota|   6|  F|1882|107847|      0.01| 0.042|
# |   Patience|   6|  F|1882|107847|      0.01| 0.042|
# |      Paula|   6|  F|1882|107847|      0.01| 0.042|
# |      Peggy|   6|  F|1882|107847|      0.01| 0.042|
# |    Phillis|   6|  F|1882|107847|      0.01| 0.042|
# |  Philomene|   6|  F|1882|107847|      0.01| 0.043|
# |     Ramona|   6|  F|1882|107847|      0.01| 0.043|
# |    Rozella|   6|  F|1882|107847|      0.01| 0.043|
# |     Ruthie|   6|  F|1882|107847|      0.01| 0.043|
# |     Salina|   6|  F|1882|107847|      0.01| 0.043|
# |      Sibyl|   6|  F|1882|107847|      0.01| 0.043|
# |      Sinda|   6|  F|1882|107847|      0.01| 0.043|
# |    Tabitha|   6|  F|1882|107847|      0.01| 0.043|
# |    Texanna|   6|  F|1882|107847|      0.01| 0.043|
# |      Texie|   6|  F|1882|107847|      0.01| 0.043|
# |    Therese|   6|  F|1882|107847|      0.01| 0.044|
# |      Tilla|   6|  F|1882|107847|      0.01| 0.044|
# |     Tinnie|   6|  F|1882|107847|      0.01| 0.044|
# |    Valeria|   6|  F|1882|107847|      0.01| 0.044|
# |     Vashti|   6|  F|1882|107847|      0.01| 0.044|
# |      Vella|   6|  F|1882|107847|      0.01| 0.044|
# |     Verdie|   6|  F|1882|107847|      0.01| 0.044|
# |      Verne|   6|  F|1882|107847|      0.01| 0.044|
# |       Veva|   6|  F|1882|107847|      0.01| 0.044|
# |       Vicy|   6|  F|1882|107847|      0.01| 0.044|
# |      Viney|   6|  F|1882|107847|      0.01| 0.045|
# |      Wilda|   6|  F|1882|107847|      0.01| 0.045|
# |      Zelda|   6|  F|1882|107847|      0.01| 0.045|
# |       Zena|   6|  F|1882|107847|      0.01| 0.045|
# |       Zita|   6|  F|1882|107847|      0.01| 0.045|
# |      Berta|  26|  F|1882|107847|      0.02| 0.045|
# |       Fern|  26|  F|1882|107847|      0.02| 0.045|
# |       Floy|  26|  F|1882|107847|      0.02| 0.046|
# |     Lavina|  26|  F|1882|107847|      0.02| 0.046|
# |        Ila|  25|  F|1882|107847|      0.02| 0.046|
# |    Juanita|  25|  F|1882|107847|      0.02| 0.046|
# |     Lessie|  25|  F|1882|107847|      0.02| 0.046|
# |     Mahala|  25|  F|1882|107847|      0.02| 0.047|
# |    Melvina|  25|  F|1882|107847|      0.02| 0.047|
# |      Phebe|  25|  F|1882|107847|      0.02| 0.047|
# |       Tena|  25|  F|1882|107847|      0.02| 0.047|
# |        Zoe|  25|  F|1882|107847|      0.02| 0.047|
# |     Almeda|  24|  F|1882|107847|      0.02| 0.048|
# |     Angela|  24|  F|1882|107847|      0.02| 0.048|
# |      Cecil|  24|  F|1882|107847|      0.02| 0.048|
# | Clementine|  24|  F|1882|107847|      0.02| 0.048|
# |     Edythe|  24|  F|1882|107847|      0.02| 0.048|
# |      Hanna|  24|  F|1882|107847|      0.02| 0.049|
# |    Johnnie|  24|  F|1882|107847|      0.02| 0.049|
# |     Lilian|  24|  F|1882|107847|      0.02| 0.049|
# |        Nan|  24|  F|1882|107847|      0.02| 0.049|
# |    Pearlie|  24|  F|1882|107847|      0.02| 0.049|
# |   Veronica|  24|  F|1882|107847|      0.02|  0.05|
# |     Vinnie|  24|  F|1882|107847|      0.02|  0.05|
# |     Adelia|  23|  F|1882|107847|      0.02|  0.05|
# |    Charles|  23|  F|1882|107847|      0.02|  0.05|
# |     Pattie|  23|  F|1882|107847|      0.02|  0.05|
# |     Pinkie|  23|  F|1882|107847|      0.02| 0.051|
# |      Retta|  23|  F|1882|107847|      0.02| 0.051|
# |  Annabelle|  22|  F|1882|107847|      0.02| 0.051|
# |  Constance|  22|  F|1882|107847|      0.02| 0.051|
# |       Iona|  22|  F|1882|107847|      0.02| 0.051|
# |    Isabell|  22|  F|1882|107847|      0.02| 0.052|
# |     Jimmie|  22|  F|1882|107847|      0.02| 0.052|
# |      Julie|  22|  F|1882|107847|      0.02| 0.052|
# |       June|  22|  F|1882|107847|      0.02| 0.052|
# |   Kathleen|  22|  F|1882|107847|      0.02| 0.052|
# |      Lucie|  22|  F|1882|107847|      0.02| 0.053|
# |     Mariah|  22|  F|1882|107847|      0.02| 0.053|
# |       Neva|  22|  F|1882|107847|      0.02| 0.053|
# |    Susanna|  22|  F|1882|107847|      0.02| 0.053|
# |     Agatha|  21|  F|1882|107847|      0.02| 0.053|
# |        Ava|  21|  F|1882|107847|      0.02| 0.054|
# |      Clare|  21|  F|1882|107847|      0.02| 0.054|
# |    Frankie|  21|  F|1882|107847|      0.02| 0.054|
# |      Leota|  21|  F|1882|107847|      0.02| 0.054|
# |      Lotta|  21|  F|1882|107847|      0.02| 0.054|
# |      Ludie|  21|  F|1882|107847|      0.02| 0.055|
# |   Marcella|  21|  F|1882|107847|      0.02| 0.055|
# |     Margie|  21|  F|1882|107847|      0.02| 0.055|
# |      Minna|  21|  F|1882|107847|      0.02| 0.055|
# |   Missouri|  21|  F|1882|107847|      0.02| 0.055|
# |      Myrta|  21|  F|1882|107847|      0.02| 0.056|
# |    Octavia|  21|  F|1882|107847|      0.02| 0.056|
# |       Rita|  21|  F|1882|107847|      0.02| 0.056|
# |      Vesta|  21|  F|1882|107847|      0.02| 0.056|
# |       Vida|  21|  F|1882|107847|      0.02| 0.056|
# |      Zelma|  21|  F|1882|107847|      0.02| 0.057|
# |       Zula|  21|  F|1882|107847|      0.02| 0.057|
# |      Anita|  20|  F|1882|107847|      0.02| 0.057|
# |      Dixie|  20|  F|1882|107847|      0.02| 0.057|
# |      Ettie|  20|  F|1882|107847|      0.02| 0.057|
# |       Faye|  20|  F|1882|107847|      0.02| 0.058|
# |  Georgiana|  20|  F|1882|107847|      0.02| 0.058|
# |     Helene|  20|  F|1882|107847|      0.02| 0.058|
# |     Lennie|  20|  F|1882|107847|      0.02| 0.058|
# |      Lucia|  20|  F|1882|107847|      0.02| 0.058|
# |     Maudie|  20|  F|1882|107847|      0.02| 0.059|
# |    Ottilie|  20|  F|1882|107847|      0.02| 0.059|
# |   Savannah|  20|  F|1882|107847|      0.02| 0.059|
# |     Bonnie|  19|  F|1882|107847|      0.02| 0.059|
# |      Clyde|  19|  F|1882|107847|      0.02| 0.059|
# |      Donna|  19|  F|1882|107847|      0.02|  0.06|
# |     Gracie|  19|  F|1882|107847|      0.02|  0.06|
# |     Jannie|  19|  F|1882|107847|      0.02|  0.06|
# |      Kitty|  19|  F|1882|107847|      0.02|  0.06|
# |     Lenore|  19|  F|1882|107847|      0.02|  0.06|
# |    Leonora|  19|  F|1882|107847|      0.02| 0.061|
# |    Letitia|  19|  F|1882|107847|      0.02| 0.061|
# |      Louie|  19|  F|1882|107847|      0.02| 0.061|
# |      Rilla|  19|  F|1882|107847|      0.02| 0.061|
# |       Sena|  19|  F|1882|107847|      0.02| 0.061|
# |     Tessie|  19|  F|1882|107847|      0.02| 0.062|
# |     Adella|  18|  F|1882|107847|      0.02| 0.062|
# |      Alida|  18|  F|1882|107847|      0.02| 0.062|
# |      Altha|  18|  F|1882|107847|      0.02| 0.062|
# |    Aurelia|  18|  F|1882|107847|      0.02| 0.062|
# |      Betsy|  18|  F|1882|107847|      0.02| 0.063|
# |       Cleo|  18|  F|1882|107847|      0.02| 0.063|
# |     Donnie|  18|  F|1882|107847|      0.02| 0.063|
# |      James|  18|  F|1882|107847|      0.02| 0.063|
# |    Lavinia|  18|  F|1882|107847|      0.02| 0.063|
# |       Meda|  18|  F|1882|107847|      0.02| 0.064|
# |     Nevada|  18|  F|1882|107847|      0.02| 0.064|
# |        Ona|  18|  F|1882|107847|      0.02| 0.064|
# |    Rosella|  18|  F|1882|107847|      0.02| 0.064|
# |        Una|  18|  F|1882|107847|      0.02| 0.064|
# |  Winnifred|  18|  F|1882|107847|      0.02| 0.065|
# |       Adda|  17|  F|1882|107847|      0.02| 0.065|
# |      Adela|  17|  F|1882|107847|      0.02| 0.065|
# |     Daisie|  17|  F|1882|107847|      0.02| 0.065|
# |     Elmira|  17|  F|1882|107847|      0.02| 0.065|
# |     Emelia|  17|  F|1882|107847|      0.02| 0.066|
# |      Henry|  17|  F|1882|107847|      0.02| 0.066|
# |   Marietta|  17|  F|1882|107847|      0.02| 0.066|
# |      Mazie|  17|  F|1882|107847|      0.02| 0.066|
# |      Patsy|  17|  F|1882|107847|      0.02| 0.066|
# |        Rae|  17|  F|1882|107847|      0.02| 0.067|
# |      Velma|  17|  F|1882|107847|      0.02| 0.067|
# |       Zona|  17|  F|1882|107847|      0.02| 0.067|
# |    Cecilia|  37|  F|1882|107847|      0.03| 0.067|
# |      Ellie|  37|  F|1882|107847|      0.03| 0.068|
# |       Nola|  37|  F|1882|107847|      0.03| 0.068|
# |       Nona|  37|  F|1882|107847|      0.03| 0.068|
# |      Dolly|  36|  F|1882|107847|      0.03| 0.068|
# |      Linda|  36|  F|1882|107847|      0.03| 0.069|
# | Antoinette|  35|  F|1882|107847|      0.03| 0.069|
# |      Janet|  35|  F|1882|107847|      0.03| 0.069|
# |  Priscilla|  35|  F|1882|107847|      0.03|  0.07|
# |    Roberta|  35|  F|1882|107847|      0.03|  0.07|
# |      Angie|  34|  F|1882|107847|      0.03|  0.07|
# |  Ernestine|  34|  F|1882|107847|      0.03| 0.071|
# |        Fay|  34|  F|1882|107847|      0.03| 0.071|
# | Georgianna|  34|  F|1882|107847|      0.03| 0.071|
# |     Lorena|  34|  F|1882|107847|      0.03| 0.071|
# |      Orpha|  34|  F|1882|107847|      0.03| 0.072|
# |      Artie|  33|  F|1882|107847|      0.03| 0.072|
# |      Chloe|  33|  F|1882|107847|      0.03| 0.072|
# |    Corinne|  33|  F|1882|107847|      0.03| 0.073|
# |    Flossie|  33|  F|1882|107847|      0.03| 0.073|
# |       Lona|  33|  F|1882|107847|      0.03| 0.073|
# |  Magdalena|  33|  F|1882|107847|      0.03| 0.074|
# |        Oma|  33|  F|1882|107847|      0.03| 0.074|
# |     Tennie|  33|  F|1882|107847|      0.03| 0.074|
# |     George|  32|  F|1882|107847|      0.03| 0.074|
# |      Norma|  32|  F|1882|107847|      0.03| 0.075|
# |       Zora|  32|  F|1882|107847|      0.03| 0.075|
# |    Bridget|  31|  F|1882|107847|      0.03| 0.075|
# |      Dovie|  31|  F|1882|107847|      0.03| 0.076|
# |        Eda|  31|  F|1882|107847|      0.03| 0.076|
# |     Elvira|  31|  F|1882|107847|      0.03| 0.076|
# |       Erma|  31|  F|1882|107847|      0.03| 0.077|
# |    William|  31|  F|1882|107847|      0.03| 0.077|
# |    Charity|  30|  F|1882|107847|      0.03| 0.077|
# |     Claire|  30|  F|1882|107847|      0.03| 0.077|
# |      Molly|  30|  F|1882|107847|      0.03| 0.078|
# |      Alpha|  29|  F|1882|107847|      0.03| 0.078|
# |   Angeline|  29|  F|1882|107847|      0.03| 0.078|
# |  Elisabeth|  29|  F|1882|107847|      0.03| 0.079|
# |      Elise|  29|  F|1882|107847|      0.03| 0.079|
# |       Elsa|  29|  F|1882|107847|      0.03| 0.079|
# |   Kathrine|  29|  F|1882|107847|      0.03|  0.08|
# |      Leora|  29|  F|1882|107847|      0.03|  0.08|
# |   Madeline|  29|  F|1882|107847|      0.03|  0.08|
# |   Maybelle|  29|  F|1882|107847|      0.03|  0.08|
# |       Vina|  29|  F|1882|107847|      0.03| 0.081|
# |    Antonia|  28|  F|1882|107847|      0.03| 0.081|
# |       Dona|  28|  F|1882|107847|      0.03| 0.081|
# |       Evie|  28|  F|1882|107847|      0.03| 0.082|
# |     Pearle|  28|  F|1882|107847|      0.03| 0.082|
# |       Tina|  28|  F|1882|107847|      0.03| 0.082|
# |       Adah|  27|  F|1882|107847|      0.03| 0.083|
# |    Annette|  27|  F|1882|107847|      0.03| 0.083|
# |     Blanch|  27|  F|1882|107847|      0.03| 0.083|
# |     Cecile|  27|  F|1882|107847|      0.03| 0.083|
# |  Harriette|  27|  F|1882|107847|      0.03| 0.084|
# |        Lue|  27|  F|1882|107847|      0.03| 0.084|
# |     Vivian|  27|  F|1882|107847|      0.03| 0.084|
# |     Violet|  48|  F|1882|107847|      0.04| 0.085|
# |     Dessie|  47|  F|1882|107847|      0.04| 0.085|
# |       Elma|  47|  F|1882|107847|      0.04| 0.086|
# |     Geneva|  47|  F|1882|107847|      0.04| 0.086|
# |    Georgie|  47|  F|1882|107847|      0.04| 0.086|
# |      Leola|  47|  F|1882|107847|      0.04| 0.087|
# |       Lura|  47|  F|1882|107847|      0.04| 0.087|
# |      Sudie|  47|  F|1882|107847|      0.04| 0.088|
# |     Gladys|  46|  F|1882|107847|      0.04| 0.088|
# |        Ivy|  46|  F|1882|107847|      0.04| 0.088|
# |    Cynthia|  45|  F|1882|107847|      0.04| 0.089|
# |     Emilie|  45|  F|1882|107847|      0.04| 0.089|
# |    Rosetta|  45|  F|1882|107847|      0.04|  0.09|
# |     Cassie|  44|  F|1882|107847|      0.04|  0.09|
# |   Isabella|  44|  F|1882|107847|      0.04|  0.09|
# |      Lilla|  44|  F|1882|107847|      0.04| 0.091|
# |  Catharine|  43|  F|1882|107847|      0.04| 0.091|
# |        Lee|  43|  F|1882|107847|      0.04| 0.092|
# |    Malinda|  43|  F|1882|107847|      0.04| 0.092|
# |     Regina|  43|  F|1882|107847|      0.04| 0.092|
# |      Freda|  42|  F|1882|107847|      0.04| 0.093|
# |     Marian|  42|  F|1882|107847|      0.04| 0.093|
# |     Goldie|  41|  F|1882|107847|      0.04| 0.094|
# |       Lina|  41|  F|1882|107847|      0.04| 0.094|
# |     Linnie|  41|  F|1882|107847|      0.04| 0.094|
# |      Madge|  41|  F|1882|107847|      0.04| 0.095|
# |      Mandy|  41|  F|1882|107847|      0.04| 0.095|
# |    Melissa|  41|  F|1882|107847|      0.04| 0.096|
# |      Polly|  41|  F|1882|107847|      0.04| 0.096|
# |       John|  40|  F|1882|107847|      0.04| 0.096|
# |     Kittie|  40|  F|1882|107847|      0.04| 0.097|
# |      Letha|  40|  F|1882|107847|      0.04| 0.097|
# |    Mabelle|  40|  F|1882|107847|      0.04| 0.098|
# |   Marjorie|  40|  F|1882|107847|      0.04| 0.098|
# |     Miriam|  40|  F|1882|107847|      0.04| 0.098|
# |    Rosalie|  40|  F|1882|107847|      0.04| 0.099|
# |   Cordelia|  39|  F|1882|107847|      0.04| 0.099|
# |    Margret|  39|  F|1882|107847|      0.04|   0.1|
# |       Bell|  38|  F|1882|107847|      0.04|   0.1|
# |       Lyda|  38|  F|1882|107847|      0.04|   0.1|
# |     Mertie|  38|  F|1882|107847|      0.04| 0.101|
# |      Nelle|  59|  F|1882|107847|      0.05| 0.101|
# |      Hilda|  58|  F|1882|107847|      0.05| 0.102|
# |       Irma|  58|  F|1882|107847|      0.05| 0.102|
# |     Lucile|  58|  F|1882|107847|      0.05| 0.103|
# |    Bernice|  57|  F|1882|107847|      0.05| 0.103|
# |       Leah|  56|  F|1882|107847|      0.05| 0.104|
# |    Minerva|  56|  F|1882|107847|      0.05| 0.104|
# |    Ophelia|  56|  F|1882|107847|      0.05| 0.105|
# |    Cecelia|  55|  F|1882|107847|      0.05| 0.105|
# |       Lora|  55|  F|1882|107847|      0.05| 0.106|
# |    Francis|  54|  F|1882|107847|      0.05| 0.106|
# |      Naomi|  54|  F|1882|107847|      0.05| 0.107|
# |      Selma|  54|  F|1882|107847|      0.05| 0.107|
# |     Alvina|  53|  F|1882|107847|      0.05| 0.108|
# | Marguerite|  52|  F|1882|107847|      0.05| 0.108|
# |     Olivia|  52|  F|1882|107847|      0.05| 0.109|
# |     Virgie|  52|  F|1882|107847|      0.05| 0.109|
# |    Louella|  51|  F|1882|107847|      0.05|  0.11|
# |       Meta|  51|  F|1882|107847|      0.05|  0.11|
# |     Frieda|  50|  F|1882|107847|      0.05| 0.111|
# |     Teresa|  50|  F|1882|107847|      0.05| 0.111|
# |      Zella|  50|  F|1882|107847|      0.05| 0.112|
# |    Claudia|  49|  F|1882|107847|      0.05| 0.112|
# |      Fanny|  49|  F|1882|107847|      0.05| 0.113|
# |    Adeline|  70|  F|1882|107847|      0.06| 0.113|
# |     Gussie|  70|  F|1882|107847|      0.06| 0.114|
# |     Lenora|  70|  F|1882|107847|      0.06| 0.115|
# |      Lilly|  70|  F|1882|107847|      0.06| 0.115|
# |     Lettie|  68|  F|1882|107847|      0.06| 0.116|
# |   Mathilda|  68|  F|1882|107847|      0.06| 0.116|
# |      Hulda|  67|  F|1882|107847|      0.06| 0.117|
# |       Vera|  67|  F|1882|107847|      0.06| 0.118|
# |     Gertie|  65|  F|1882|107847|      0.06| 0.118|
# |       Lila|  65|  F|1882|107847|      0.06| 0.119|
# |   Lucretia|  65|  F|1882|107847|      0.06| 0.119|
# |      Adele|  64|  F|1882|107847|      0.06|  0.12|
# |  Christina|  64|  F|1882|107847|      0.06| 0.121|
# |   Jeanette|  64|  F|1882|107847|      0.06| 0.121|
# |       Lois|  64|  F|1882|107847|      0.06| 0.122|
# |     Myrtie|  64|  F|1882|107847|      0.06| 0.122|
# |       Olga|  64|  F|1882|107847|      0.06| 0.123|
# |     Hester|  63|  F|1882|107847|      0.06| 0.124|
# |       Lily|  63|  F|1882|107847|      0.06| 0.124|
# |     Mittie|  63|  F|1882|107847|      0.06| 0.125|
# |    Carolyn|  62|  F|1882|107847|      0.06| 0.125|
# |     Hallie|  62|  F|1882|107847|      0.06| 0.126|
# |     Phoebe|  62|  F|1882|107847|      0.06| 0.127|
# | Wilhelmina|  62|  F|1882|107847|      0.06| 0.127|
# |     Elnora|  60|  F|1882|107847|      0.06| 0.128|
# |     Helena|  60|  F|1882|107847|      0.06| 0.128|
# |       Jean|  60|  F|1882|107847|      0.06| 0.129|
# |  Jeannette|  60|  F|1882|107847|      0.06|  0.13|
# |      Abbie|  80|  F|1882|107847|      0.07|  0.13|
# |      Rhoda|  79|  F|1882|107847|      0.07| 0.131|
# |     Sylvia|  79|  F|1882|107847|      0.07| 0.132|
# |       Bess|  76|  F|1882|107847|      0.07| 0.132|
# |       Mina|  76|  F|1882|107847|      0.07| 0.133|
# |      Verna|  76|  F|1882|107847|      0.07| 0.134|
# |  Christine|  75|  F|1882|107847|      0.07| 0.134|
# |       Elva|  75|  F|1882|107847|      0.07| 0.135|
# |     Eunice|  75|  F|1882|107847|      0.07| 0.136|
# |   Adelaide|  74|  F|1882|107847|      0.07| 0.137|
# |  Genevieve|  74|  F|1882|107847|      0.07| 0.137|
# |    Johanna|  74|  F|1882|107847|      0.07| 0.138|
# |     Winnie|  74|  F|1882|107847|      0.07| 0.139|
# |    Eugenia|  73|  F|1882|107847|      0.07| 0.139|
# |      Hazel|  73|  F|1882|107847|      0.07|  0.14|
# |     Hettie|  73|  F|1882|107847|      0.07| 0.141|
# |       Lida|  73|  F|1882|107847|      0.07| 0.141|
# |     Isabel|  72|  F|1882|107847|      0.07| 0.142|
# |    Loretta|  72|  F|1882|107847|      0.07| 0.143|
# |      Roxie|  72|  F|1882|107847|      0.07| 0.144|
# |   Cornelia|  91|  F|1882|107847|      0.08| 0.144|
# |   Harriett|  91|  F|1882|107847|      0.08| 0.145|
# |    Alberta|  90|  F|1882|107847|      0.08| 0.146|
# |       Myra|  89|  F|1882|107847|      0.08| 0.147|
# |    Lucille|  85|  F|1882|107847|      0.08| 0.148|
# |        Sue|  84|  F|1882|107847|      0.08| 0.148|
# |      Leila|  83|  F|1882|107847|      0.08| 0.149|
# |   Winifred|  83|  F|1882|107847|      0.08|  0.15|
# |  Katharine|  82|  F|1882|107847|      0.08| 0.151|
# |   Isabelle|  81|  F|1882|107847|      0.08| 0.152|
# |     Dollie|  99|  F|1882|107847|      0.09| 0.152|
# |     Bertie|  96|  F|1882|107847|      0.09| 0.153|
# |       Eula|  95|  F|1882|107847|      0.09| 0.154|
# |      Lelia|  95|  F|1882|107847|      0.09| 0.155|
# |      Sally|  95|  F|1882|107847|      0.09| 0.156|
# |    Lucinda|  93|  F|1882|107847|      0.09| 0.157|
# |      Allie| 113|  F|1882|107847|       0.1| 0.158|
# |     Birdie| 113|  F|1882|107847|       0.1| 0.159|
# |      Essie| 113|  F|1882|107847|       0.1|  0.16|
# |        Ola| 113|  F|1882|107847|       0.1| 0.161|
# |     Sophie| 110|  F|1882|107847|       0.1| 0.162|
# |       Inez| 106|  F|1882|107847|       0.1| 0.163|
# |        Ina| 104|  F|1882|107847|       0.1| 0.164|
# |     Tillie| 104|  F|1882|107847|       0.1| 0.165|
# |       Nell| 103|  F|1882|107847|       0.1| 0.166|
# |       Rena| 103|  F|1882|107847|       0.1| 0.167|
# |   Beatrice| 123|  F|1882|107847|      0.11| 0.168|
# |      Betty| 123|  F|1882|107847|      0.11| 0.169|
# |     Millie| 122|  F|1882|107847|      0.11|  0.17|
# |      Maria| 121|  F|1882|107847|      0.11| 0.171|
# |       Alta| 119|  F|1882|107847|      0.11| 0.172|
# |     Luella| 117|  F|1882|107847|      0.11| 0.174|
# |    Dorothy| 115|  F|1882|107847|      0.11| 0.175|
# |        Iva| 134|  F|1882|107847|      0.12| 0.176|
# |      Janie| 134|  F|1882|107847|      0.12| 0.177|
# |    Estelle| 133|  F|1882|107847|      0.12| 0.178|
# |   Victoria| 132|  F|1882|107847|      0.12| 0.179|
# |        Lou| 131|  F|1882|107847|      0.12| 0.181|
# |    Barbara| 130|  F|1882|107847|      0.12| 0.182|
# |     Callie| 129|  F|1882|107847|      0.12| 0.183|
# |     Louisa| 128|  F|1882|107847|      0.12| 0.184|
# |      Celia| 126|  F|1882|107847|      0.12| 0.185|
# |     Evelyn| 125|  F|1882|107847|      0.12| 0.187|
# |      Mable| 125|  F|1882|107847|      0.12| 0.188|
# |      Delia| 143|  F|1882|107847|      0.13| 0.189|
# |       Lela| 143|  F|1882|107847|      0.13|  0.19|
# |     Marion| 141|  F|1882|107847|      0.13| 0.192|
# |      Mayme| 140|  F|1882|107847|      0.13| 0.193|
# |      Rosie| 140|  F|1882|107847|      0.13| 0.194|
# |     Bettie| 136|  F|1882|107847|      0.13| 0.196|
# ...
# |    Creston|   5|  M|1906|133158|       0.0|   0.0|
# |       Cruz|   5|  M|1906|133158|       0.0|   0.0|
# |      Delma|   5|  M|1906|133158|       0.0|   0.0|
# |    Dolphus|   5|  M|1906|133158|       0.0|   0.0|
# |    Domenic|   5|  M|1906|133158|       0.0|   0.0|
# |     Donnie|   5|  M|1906|133158|       0.0|   0.0|
# |       Duke|   5|  M|1906|133158|       0.0|   0.0|
# |       Eddy|   5|  M|1906|133158|       0.0|   0.0|
# |      Elder|   5|  M|1906|133158|       0.0|   0.0|
# |    Eleanor|   5|  M|1906|133158|       0.0|   0.0|
# |      Elick|   5|  M|1906|133158|       0.0|   0.0|
# |     Elliot|   5|  M|1906|133158|       0.0|   0.0|
# |    Ellison|   5|  M|1906|133158|       0.0|   0.0|
# |   Elsworth|   5|  M|1906|133158|       0.0|   0.0|
# |    Ephraim|   5|  M|1906|133158|       0.0|   0.0|
# |       Erie|   5|  M|1906|133158|       0.0|   0.0|
# |    Esteban|   5|  M|1906|133158|       0.0|   0.0|
# |     Esther|   5|  M|1906|133158|       0.0|   0.0|
# |    Eusebio|   5|  M|1906|133158|       0.0|   0.0|
# |       Fern|   5|  M|1906|133158|       0.0|   0.0|
# |      Field|   5|  M|1906|133158|       0.0|   0.0|
# |    Fleming|   5|  M|1906|133158|       0.0|   0.0|
# |      Flora|   5|  M|1906|133158|       0.0|   0.0|
# |        Foy|   5|  M|1906|133158|       0.0|   0.0|
# |      Garth|   5|  M|1906|133158|       0.0|   0.0|
# |        Gay|   5|  M|1906|133158|       0.0|   0.0|
# |      Gayle|   5|  M|1906|133158|       0.0|   0.0|
# |    Gerardo|   5|  M|1906|133158|       0.0|   0.0|
# |     Geroge|   5|  M|1906|133158|       0.0|   0.0|
# |   Geronimo|   5|  M|1906|133158|       0.0|   0.0|
# |     Gibson|   5|  M|1906|133158|       0.0|   0.0|
# |   Glenwood|   5|  M|1906|133158|       0.0|   0.0|
# |       Gray|   5|  M|1906|133158|       0.0|   0.0|
# |    Graydon|   5|  M|1906|133158|       0.0|   0.0|
# |     Gurney|   5|  M|1906|133158|       0.0|   0.0|
# |      Hence|   5|  M|1906|133158|       0.0|   0.0|
# |   Hershell|   5|  M|1906|133158|       0.0|   0.0|
# |     Hobson|   5|  M|1906|133158|       0.0|   0.0|
# |       Holt|   5|  M|1906|133158|       0.0|   0.0|
# |       Hope|   5|  M|1906|133158|       0.0|   0.0|
# |        Hoy|   5|  M|1906|133158|       0.0|   0.0|
# |     Hudson|   5|  M|1906|133158|       0.0|   0.0|
# |   Humphrey|   5|  M|1906|133158|       0.0|   0.0|
# |       Inez|   5|  M|1906|133158|       0.0|   0.0|
# |       Irby|   5|  M|1906|133158|       0.0|   0.0|
# |     Isabel|   5|  M|1906|133158|       0.0|   0.0|
# |     Isidor|   5|  M|1906|133158|       0.0|   0.0|
# |     Isreal|   5|  M|1906|133158|       0.0|   0.0|
# |      Jamie|   5|  M|1906|133158|       0.0|   0.0|
# |        Jan|   5|  M|1906|133158|       0.0|   0.0|
# |    Joaquin|   5|  M|1906|133158|       0.0|   0.0|
# |      Jonah|   5|  M|1906|133158|       0.0|   0.0|
# |       Jule|   5|  M|1906|133158|       0.0|   0.0|
# |     Juluis|   5|  M|1906|133158|       0.0|   0.0|
# |        Kay|   5|  M|1906|133158|       0.0|   0.0|
# |     Kelley|   5|  M|1906|133158|       0.0|   0.0|
# |    Kendall|   5|  M|1906|133158|       0.0|   0.0|
# |    Kennard|   5|  M|1906|133158|       0.0|   0.0|
# |      Kirby|   5|  M|1906|133158|       0.0|   0.0|
# |       Kirk|   5|  M|1906|133158|       0.0|   0.0|
# |       Kurt|   5|  M|1906|133158|       0.0|   0.0|
# |     Larkin|   5|  M|1906|133158|       0.0|   0.0|
# |  Lawerence|   5|  M|1906|133158|       0.0|   0.0|
# |    Lazarus|   5|  M|1906|133158|       0.0|   0.0|
# |     Leamon|   5|  M|1906|133158|       0.0|   0.0|
# |     Lehman|   5|  M|1906|133158|       0.0|   0.0|
# |      Leigh|   5|  M|1906|133158|       0.0|   0.0|
# |       Less|   5|  M|1906|133158|       0.0|   0.0|
# |     Lessie|   5|  M|1906|133158|       0.0|   0.0|
# |    Lindley|   5|  M|1906|133158|       0.0|   0.0|
# |     Linton|   5|  M|1906|133158|       0.0|   0.0|
# |      Linus|   5|  M|1906|133158|       0.0|   0.0|
# |    Lorenza|   5|  M|1906|133158|       0.0|   0.0|
# |      Loyce|   5|  M|1906|133158|       0.0|   0.0|
# |      Mamie|   5|  M|1906|133158|       0.0|   0.0|
# |     Manson|   5|  M|1906|133158|       0.0|   0.0|
# |   Matthews|   5|  M|1906|133158|       0.0|   0.0|
# |      Maury|   5|  M|1906|133158|       0.0|   0.0|
# |      Milan|   5|  M|1906|133158|       0.0|   0.0|
# |        Moe|   5|  M|1906|133158|       0.0|   0.0|
# |     Montie|   5|  M|1906|133158|       0.0|   0.0|
# |      Moody|   5|  M|1906|133158|       0.0|   0.0|
# |     Muriel|   5|  M|1906|133158|       0.0|   0.0|
# |       Myer|   5|  M|1906|133158|       0.0|   0.0|
# |     Natale|   5|  M|1906|133158|       0.0|   0.0|
# |     Nathon|   5|  M|1906|133158|       0.0|   0.0|
# |  Natividad|   5|  M|1906|133158|       0.0|   0.0|
# |     Nestor|   5|  M|1906|133158|       0.0|   0.0|
# |     Norvel|   5|  M|1906|133158|       0.0|   0.0|
# |     Oakley|   5|  M|1906|133158|       0.0|   0.0|
# |       Oris|   5|  M|1906|133158|       0.0|   0.0|
# |       Osie|   5|  M|1906|133158|       0.0|   0.0|
# |      Ossie|   5|  M|1906|133158|       0.0|   0.0|
# |   Perfecto|   5|  M|1906|133158|       0.0|   0.0|
# |    Presley|   5|  M|1906|133158|       0.0|   0.0|
# |      Price|   5|  M|1906|133158|       0.0|   0.0|
# |    Radford|   5|  M|1906|133158|       0.0|   0.0|
# |    Rayford|   5|  M|1906|133158|       0.0|   0.0|
# |       Reno|   5|  M|1906|133158|       0.0|   0.0|
# |     Reubin|   5|  M|1906|133158|       0.0|   0.0|
# |      Rolla|   5|  M|1906|133158|       0.0|   0.0|
# |   Roosvelt|   5|  M|1906|133158|       0.0|   0.0|
# |       Rosa|   5|  M|1906|133158|       0.0|   0.0|
# |      Rosco|   5|  M|1906|133158|       0.0|   0.0|
# |        Rue|   5|  M|1906|133158|       0.0|   0.0|
# |     Rueben|   5|  M|1906|133158|       0.0|   0.0|
# |   Schuyler|   5|  M|1906|133158|       0.0|   0.0|
# |    Seaborn|   5|  M|1906|133158|       0.0|   0.0|
# |  Sebastian|   5|  M|1906|133158|       0.0|   0.0|
# |    Shannon|   5|  M|1906|133158|       0.0|   0.0|
# |    Shellie|   5|  M|1906|133158|       0.0|   0.0|
# |   Sheridan|   5|  M|1906|133158|       0.0|   0.0|
# |  Silvester|   5|  M|1906|133158|       0.0|   0.0|
# |      Stacy|   5|  M|1906|133158|       0.0|   0.0|
# |    Stephan|   5|  M|1906|133158|       0.0|   0.0|
# |     Sylvia|   5|  M|1906|133158|       0.0|   0.0|
# |    Theresa|   5|  M|1906|133158|       0.0|   0.0|
# |       Toby|   5|  M|1906|133158|       0.0|   0.0|
# |      Verle|   5|  M|1906|133158|       0.0|   0.0|
# |    Vicente|   5|  M|1906|133158|       0.0|   0.0|
# |     Vinton|   5|  M|1906|133158|       0.0|   0.0|
# |   Virginia|   5|  M|1906|133158|       0.0|   0.0|
# |       Watt|   5|  M|1906|133158|       0.0|   0.0|
# |    Waverly|   5|  M|1906|133158|       0.0|   0.0|
# |       Whit|   5|  M|1906|133158|       0.0|   0.0|
# |    Willman|   5|  M|1906|133158|       0.0|   0.0|
# |   Winifred|   5|  M|1906|133158|       0.0|   0.0|
# |    Winslow|   5|  M|1906|133158|       0.0|   0.0|
# |       Wray|   5|  M|1906|133158|       0.0|   0.0|
# |      Wyman|   5|  M|1906|133158|       0.0|   0.0|
# |     Zeddie|   5|  M|1906|133158|       0.0|   0.0|
# |       Aron|  19|  M|1906|133158|      0.01|   0.0|
# |      Bruno|  19|  M|1906|133158|      0.01|   0.0|
# |     Dorsey|  19|  M|1906|133158|      0.01|   0.0|
# |     Elmore|  19|  M|1906|133158|      0.01|   0.0|
# |      Emmet|  19|  M|1906|133158|      0.01| 0.001|
# |   Frederic|  19|  M|1906|133158|      0.01| 0.001|
# |    General|  19|  M|1906|133158|      0.01| 0.001|
# |     Hobart|  19|  M|1906|133158|      0.01| 0.001|
# |       Hoyt|  19|  M|1906|133158|      0.01| 0.001|
# |     Israel|  19|  M|1906|133158|      0.01| 0.001|
# |    Linwood|  19|  M|1906|133158|      0.01| 0.001|
# |       Luis|  19|  M|1906|133158|      0.01| 0.001|
# |    Merritt|  19|  M|1906|133158|      0.01| 0.001|
# |     Miguel|  19|  M|1906|133158|      0.01| 0.001|
# |       Olaf|  19|  M|1906|133158|      0.01| 0.002|
# |       Reed|  19|  M|1906|133158|      0.01| 0.002|
# |    Rolland|  19|  M|1906|133158|      0.01| 0.002|
# |       Rose|  19|  M|1906|133158|      0.01| 0.002|
# |       Rudy|  19|  M|1906|133158|      0.01| 0.002|
# |       Ruth|  19|  M|1906|133158|      0.01| 0.002|
# |     Santos|  19|  M|1906|133158|      0.01| 0.002|
# |      Smith|  19|  M|1906|133158|      0.01| 0.002|
# |      Vance|  19|  M|1906|133158|      0.01| 0.002|
# |     Wilton|  19|  M|1906|133158|      0.01| 0.002|
# |      Abram|  18|  M|1906|133158|      0.01| 0.003|
# |   Adolphus|  18|  M|1906|133158|      0.01| 0.003|
# |     Arther|  18|  M|1906|133158|      0.01| 0.003|
# |       Burt|  18|  M|1906|133158|      0.01| 0.003|
# |      Cleve|  18|  M|1906|133158|      0.01| 0.003|
# |   Eldridge|  18|  M|1906|133158|      0.01| 0.003|
# |      Elias|  18|  M|1906|133158|      0.01| 0.003|
# |  Henderson|  18|  M|1906|133158|      0.01| 0.003|
# |   Ignatius|  18|  M|1906|133158|      0.01| 0.003|
# |      Jonas|  18|  M|1906|133158|      0.01| 0.003|
# |     Junior|  18|  M|1906|133158|      0.01| 0.004|
# |    Lincoln|  18|  M|1906|133158|      0.01| 0.004|
# |    Lindsey|  18|  M|1906|133158|      0.01| 0.004|
# |       Phil|  18|  M|1906|133158|      0.01| 0.004|
# |   Richmond|  18|  M|1906|133158|      0.01| 0.004|
# |      Sandy|  18|  M|1906|133158|      0.01| 0.004|
# |       Saul|  18|  M|1906|133158|      0.01| 0.004|
# |     Turner|  18|  M|1906|133158|      0.01| 0.004|
# |  Valentine|  18|  M|1906|133158|      0.01| 0.004|
# |      Waldo|  18|  M|1906|133158|      0.01| 0.004|
# |   Winfield|  18|  M|1906|133158|      0.01| 0.005|
# |      Albin|  17|  M|1906|133158|      0.01| 0.005|
# |        Asa|  17|  M|1906|133158|      0.01| 0.005|
# |      Avery|  17|  M|1906|133158|      0.01| 0.005|
# |   Chauncey|  17|  M|1906|133158|      0.01| 0.005|
# |      Clint|  17|  M|1906|133158|      0.01| 0.005|
# |      Green|  17|  M|1906|133158|      0.01| 0.005|
# |    Gustave|  17|  M|1906|133158|      0.01| 0.005|
# |      Hardy|  17|  M|1906|133158|      0.01| 0.005|
# |    Isidore|  17|  M|1906|133158|      0.01| 0.005|
# |      Lamar|  17|  M|1906|133158|      0.01| 0.006|
# |     Lawson|  17|  M|1906|133158|      0.01| 0.006|
# |      Loyal|  17|  M|1906|133158|      0.01| 0.006|
# |     Murphy|  17|  M|1906|133158|      0.01| 0.006|
# |    Orlando|  17|  M|1906|133158|      0.01| 0.006|
# |       Seth|  17|  M|1906|133158|      0.01| 0.006|
# |    Sheldon|  17|  M|1906|133158|      0.01| 0.006|
# |      Teddy|  17|  M|1906|133158|      0.01| 0.006|
# |       Theo|  17|  M|1906|133158|      0.01| 0.006|
# |   Thornton|  17|  M|1906|133158|      0.01| 0.006|
# |      Tomas|  17|  M|1906|133158|      0.01| 0.007|
# |     Travis|  17|  M|1906|133158|      0.01| 0.007|
# |     Warner|  17|  M|1906|133158|      0.01| 0.007|
# |     Alford|  16|  M|1906|133158|      0.01| 0.007|
# |  Archibald|  16|  M|1906|133158|      0.01| 0.007|
# |     Benito|  16|  M|1906|133158|      0.01| 0.007|
# |       Burl|  16|  M|1906|133158|      0.01| 0.007|
# |       Cary|  16|  M|1906|133158|      0.01| 0.007|
# |   Clarance|  16|  M|1906|133158|      0.01| 0.007|
# |      Craig|  16|  M|1906|133158|      0.01| 0.007|
# |      Ethel|  16|  M|1906|133158|      0.01| 0.008|
# |    Gabriel|  16|  M|1906|133158|      0.01| 0.008|
# |       Gary|  16|  M|1906|133158|      0.01| 0.008|
# |     Golden|  16|  M|1906|133158|      0.01| 0.008|
# |    Gregory|  16|  M|1906|133158|      0.01| 0.008|
# |       Hans|  16|  M|1906|133158|      0.01| 0.008|
# |     Hermon|  16|  M|1906|133158|      0.01| 0.008|
# |    Laverne|  16|  M|1906|133158|      0.01| 0.008|
# |       Lois|  16|  M|1906|133158|      0.01| 0.008|
# |   Margaret|  16|  M|1906|133158|      0.01| 0.008|
# |      Meyer|  16|  M|1906|133158|      0.01| 0.009|
# |       Odie|  16|  M|1906|133158|      0.01| 0.009|
# |       Olen|  16|  M|1906|133158|      0.01| 0.009|
# |     Parker|  16|  M|1906|133158|      0.01| 0.009|
# |   Salvador|  16|  M|1906|133158|      0.01| 0.009|
# |      Tracy|  16|  M|1906|133158|      0.01| 0.009|
# |   Adelbert|  15|  M|1906|133158|      0.01| 0.009|
# |      Alvie|  15|  M|1906|133158|      0.01| 0.009|
# |      Artie|  15|  M|1906|133158|      0.01| 0.009|
# |     Bailey|  15|  M|1906|133158|      0.01| 0.009|
# |   Benedict|  15|  M|1906|133158|      0.01|  0.01|
# |      Buddy|  15|  M|1906|133158|      0.01|  0.01|
# |      Carey|  15|  M|1906|133158|      0.01|  0.01|
# |     Carter|  15|  M|1906|133158|      0.01|  0.01|
# |    Coleman|  15|  M|1906|133158|      0.01|  0.01|
# |       Dana|  15|  M|1906|133158|      0.01|  0.01|
# |     Elisha|  15|  M|1906|133158|      0.01|  0.01|
# |  Elizabeth|  15|  M|1906|133158|      0.01|  0.01|
# |      Elwin|  15|  M|1906|133158|      0.01|  0.01|
# |        Fay|  15|  M|1906|133158|      0.01|  0.01|
# |  Guadalupe|  15|  M|1906|133158|      0.01| 0.011|
# |    Hillard|  15|  M|1906|133158|      0.01| 0.011|
# |     Hilton|  15|  M|1906|133158|      0.01| 0.011|
# |     Huston|  15|  M|1906|133158|      0.01| 0.011|
# |      Jason|  15|  M|1906|133158|      0.01| 0.011|
# |        Lon|  15|  M|1906|133158|      0.01| 0.011|
# |      Marie|  15|  M|1906|133158|      0.01| 0.011|
# |      Mario|  15|  M|1906|133158|      0.01| 0.011|
# |     Oswald|  15|  M|1906|133158|      0.01| 0.011|
# |    Raleigh|  15|  M|1906|133158|      0.01| 0.011|
# |     Rollin|  15|  M|1906|133158|      0.01| 0.012|
# |   Talmadge|  15|  M|1906|133158|      0.01| 0.012|
# |        Tim|  15|  M|1906|133158|      0.01| 0.012|
# |      Alden|  14|  M|1906|133158|      0.01| 0.012|
# |    Alfredo|  14|  M|1906|133158|      0.01| 0.012|
# |      Alois|  14|  M|1906|133158|      0.01| 0.012|
# |     Andres|  14|  M|1906|133158|      0.01| 0.012|
# |     Auther|  14|  M|1906|133158|      0.01| 0.012|
# |     Barton|  14|  M|1906|133158|      0.01| 0.012|
# |      Billy|  14|  M|1906|133158|      0.01| 0.012|
# |      Brady|  14|  M|1906|133158|      0.01| 0.013|
# |      Caleb|  14|  M|1906|133158|      0.01| 0.013|
# |    Carmine|  14|  M|1906|133158|      0.01| 0.013|
# |     Cletus|  14|  M|1906|133158|      0.01| 0.013|
# |    Darrell|  14|  M|1906|133158|      0.01| 0.013|
# |      Ernst|  14|  M|1906|133158|      0.01| 0.013|
# |      Estel|  14|  M|1906|133158|      0.01| 0.013|
# |      Evans|  14|  M|1906|133158|      0.01| 0.013|
# |     Felton|  14|  M|1906|133158|      0.01| 0.013|
# |   Florence|  14|  M|1906|133158|      0.01| 0.013|
# |    Godfrey|  14|  M|1906|133158|      0.01| 0.014|
# |     Gustav|  14|  M|1906|133158|      0.01| 0.014|
# |     Harmon|  14|  M|1906|133158|      0.01| 0.014|
# |    Haywood|  14|  M|1906|133158|      0.01| 0.014|
# |      Issac|  14|  M|1906|133158|      0.01| 0.014|
# |     Justin|  14|  M|1906|133158|      0.01| 0.014|
# |        Len|  14|  M|1906|133158|      0.01| 0.014|
# |       Levy|  14|  M|1906|133158|      0.01| 0.014|
# |    Lillian|  14|  M|1906|133158|      0.01| 0.014|
# |    Madison|  14|  M|1906|133158|      0.01| 0.014|
# |  Marcellus|  14|  M|1906|133158|      0.01| 0.015|
# |    Mildred|  14|  M|1906|133158|      0.01| 0.015|
# |     Miller|  14|  M|1906|133158|      0.01| 0.015|
# |   Napoleon|  14|  M|1906|133158|      0.01| 0.015|
# |       Obie|  14|  M|1906|133158|      0.01| 0.015|
# |       Oral|  14|  M|1906|133158|      0.01| 0.015|
# |       Oran|  14|  M|1906|133158|      0.01| 0.015|
# |      Alvis|  13|  M|1906|133158|      0.01| 0.015|
# |       Anna|  13|  M|1906|133158|      0.01| 0.015|
# |       Arch|  13|  M|1906|133158|      0.01| 0.015|
# |     Ashley|  13|  M|1906|133158|      0.01| 0.016|
# |   Benjiman|  13|  M|1906|133158|      0.01| 0.016|
# |      Blair|  13|  M|1906|133158|      0.01| 0.016|
# |     Carrol|  13|  M|1906|133158|      0.01| 0.016|
# |     Carson|  13|  M|1906|133158|      0.01| 0.016|
# |    Casimir|  13|  M|1906|133158|      0.01| 0.016|
# |      Clare|  13|  M|1906|133158|      0.01| 0.016|
# |    Claudie|  13|  M|1906|133158|      0.01| 0.016|
# |   Crawford|  13|  M|1906|133158|      0.01| 0.016|
# |     Earlie|  13|  M|1906|133158|      0.01| 0.016|
# |      Emmit|  13|  M|1906|133158|      0.01| 0.017|
# |      Ewell|  13|  M|1906|133158|      0.01| 0.017|
# |       Ford|  13|  M|1906|133158|      0.01| 0.017|
# |     Hallie|  13|  M|1906|133158|      0.01| 0.017|
# |       Hoke|  13|  M|1906|133158|      0.01| 0.017|
# +-----------+----+---+----+------+----------+------+
# only showing top 1500 rows

# %% [markdown]
# 1. Design a function that takes as input a `year` and plots the Lorenz curve
# for that year for both sexes.

# %%
# %%
# TODO:
    
# %%

# %% [markdown]
# Gini index
# ==========
#
# The [Gini index](https://en.wikipedia.org/wiki/Gini_coefficient) is twice the surface of the area comprised between curves $y=x$
# and $y=L(x)$.
#
# Choose a formula that allows you to compute it efficiently.
#
# $$G={\frac {2\sum _{i=1}^{n}iy_{i}}{n\sum _{i=1}^{n}y_{i}}}-{\frac {n+1}{n}}.$$
#
# 1. Design a query that computes the Gini index of the `babynames` distribution
# for every `year` and `sex`.
#
# 1. Plot Gini index over time

# %%
# TODO:

# %%
# %%
# TODO:
# %%

# %% [markdown]
# Close the door, leave work area clean
# =====================================

# %%
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5c6b4d5d9db0> in <module>
# ----> 1 spark.stop()
#
# NameError: name 'spark' is not defined
